# %%
import pandas as pd

# %%
df_2017 = pd.read_csv('raw/ACSST5Y2017.S2503_data_with_overlays_2021-09-19T113628.csv', header=1)

# %%
df_2017.shape
# Out:
# (3592, 554)

# %%
df_2017.head()
# Out:
#                id                 Geographic Area Name  \
# 0  400C100US00037   Abbeville, LA Urban Cluster (2010)
# 1  400C100US00064   Abbeville, SC Urban Cluster (2010)
# 2  400C100US00091  Abbotsford, WI Urban Cluster (2010)
# 3  400C100US00118    Aberdeen, MS Urban Cluster (2010)
# 4  400C100US00145    Aberdeen, SD Urban Cluster (2010)
#
#    Estimate!!Occupied housing units!!Occupied housing units  \
# 0                                               7522
# 1                                               2016
# 2                                               1525
# 3                                               1691
# 4                                              12071
#
#    Margin of Error!!Occupied housing units MOE!!Occupied housing units  \
# 0                                                336
# 1                                                239
# 2                                                 88
# 3                                                155
# ...

# %%
#df_2017.drop([col for col in df_2017.columns if 'Median' not in col], axis = 1, inplace=True)

# %%
word = 'Median'
word2 = 'Margin'
cols_list = [m for m in df_2017.columns if word in m and word2 not in m]

# %%
cols_list.insert(0, 'Geographic Area Name')

# %%
len(cols_list)
# Out:
# 13

# %%
cols_list
# Out:
# ['Geographic Area Name',
#  'Estimate!!Occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)',
#  'Estimate!!Occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)',
#  'Estimate!!Percent occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)',
#  'Estimate!!Percent occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)',
#  'Estimate!!Owner-occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)',
#  'Estimate!!Owner-occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)',
# ...

# %%
#import re
#clean = []
#for t in cols_list:
#    clean.append(re.sub(r'^.*?Median', '', t))

# %%
median_2017_df = df_2017[cols_list]

# %%
median_2017_df.rename(columns={
    'Geographic Area Name': 'location',
    'Estimate!!Occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)': 'Median household income (dollars)',
    'Estimate!!Occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)': 'Monthly cost',
    'Estimate!!Percent occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)': 'Percent occupied income',
    'Estimate!!Percent occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)':'Percent Occupied cost',
    'Estimate!!Owner-occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)':'Owner occupied income',
    'Estimate!!Owner-occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)': 'Owner occupied cost',
    'Estimate!!Percent owner-occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)':'Percent owner occupied income',
    'Estimate!!Percent owner-occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)':'Percent owner occupied house cost',
    'Estimate!!Renter-occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)':'renter occupied income',
    'Estimate!!Renter-occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)': 'renter occupied cost',
    'Estimate!!Percent renter-occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)': 'percent renter occupied income',
    'Estimate!!Percent renter-occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)':'percent renter occupied monthly costs'
    
    
    
    
}, inplace=True)
# Out:
# C:\Users\eswan\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
median_2017_df.head()
# Out:
#                               location  Median household income (dollars)  \
# 0   Abbeville, LA Urban Cluster (2010)                              41082
# 1   Abbeville, SC Urban Cluster (2010)                              22898
# 2  Abbotsford, WI Urban Cluster (2010)                              42043
# 3    Aberdeen, MS Urban Cluster (2010)                              29317
# 4    Aberdeen, SD Urban Cluster (2010)                              47342
#
#    Monthly cost  Percent occupied income  Percent Occupied cost  \
# 0           514                    41082                    514
# 1           549                    22898                    549
# 2           608                    42043                    608
# 3           578                    29317                    578
# 4           721                    47342                    721
#
#   Owner occupied income Owner occupied cost Percent owner occupied income  \
# ...

# %%
median_2017_df[['city', 'state']] = median_2017_df['location'].str.split(',', expand=True)
# Out:
# C:\Users\eswan\anaconda3\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
median_2017_df.head()
# Out:
#                               location  Median household income (dollars)  \
# 0   Abbeville, LA Urban Cluster (2010)                              41082
# 1   Abbeville, SC Urban Cluster (2010)                              22898
# 2  Abbotsford, WI Urban Cluster (2010)                              42043
# 3    Aberdeen, MS Urban Cluster (2010)                              29317
# 4    Aberdeen, SD Urban Cluster (2010)                              47342
#
#    Monthly cost  Percent occupied income  Percent Occupied cost  \
# 0           514                    41082                    514
# 1           549                    22898                    549
# 2           608                    42043                    608
# 3           578                    29317                    578
# 4           721                    47342                    721
#
#   Owner occupied income Owner occupied cost Percent owner occupied income  \
# ...

# %%
median_2017_df['state'] = median_2017_df['state'].str.split(' ').str[1]
# Out:
# <ipython-input-187-12601e78742a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   median_2017_df['state'] = median_2017_df['state'].str.split(' ').str[1]

# %%
median_2017_df.head()
# Out:
#                               location  Median household income (dollars)  \
# 0   Abbeville, LA Urban Cluster (2010)                              41082
# 1   Abbeville, SC Urban Cluster (2010)                              22898
# 2  Abbotsford, WI Urban Cluster (2010)                              42043
# 3    Aberdeen, MS Urban Cluster (2010)                              29317
# 4    Aberdeen, SD Urban Cluster (2010)                              47342
#
#    Monthly cost  Percent occupied income  Percent Occupied cost  \
# 0           514                    41082                    514
# 1           549                    22898                    549
# 2           608                    42043                    608
# 3           578                    29317                    578
# 4           721                    47342                    721
#
#   Owner occupied income Owner occupied cost Percent owner occupied income  \
# ...

# %%
median_2017_df.drop(columns = 'location', inplace=True)
# Out:
# C:\Users\eswan\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
median_2017_df.insert(0, 'State', median_2017_df['state'])

median_2017_df.insert(0, 'City', median_2017_df['city'])

# %%
median_2017_df.drop(columns = ['city', 'state'], inplace=True)

# %%
median_2017_df['City'] = median_2017_df['City'].str.lower()
median_2017_df['State'] = median_2017_df['State'].str.lower()
# Out:
# <ipython-input-192-606f5ef153d4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   median_2017_df['City'] = median_2017_df['City'].str.lower()
# <ipython-input-192-606f5ef153d4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   median_2017_df['State'] = median_2017_df['State'].str.lower()

# %%
median_2017_df.head()
# Out:
#          City State  Median household income (dollars)  Monthly cost  \
# 0   abbeville    la                              41082           514
# 1   abbeville    sc                              22898           549
# 2  abbotsford    wi                              42043           608
# 3    aberdeen    ms                              29317           578
# 4    aberdeen    sd                              47342           721
#
#    Percent occupied income  Percent Occupied cost Owner occupied income  \
# 0                    41082                    514                 51168
# 1                    22898                    549                 32998
# 2                    42043                    608                 53068
# 3                    29317                    578                 44957
# 4                    47342                    721                 70839
#
#   Owner occupied cost Percent owner occupied income  \
# 0                 399                         51168
# ...

# %%
median_2017_df.drop(columns=['percent renter occupied income', 'percent renter occupied monthly costs',
                     'Percent owner occupied income', 'Percent owner occupied house cost', 
                      'Percent Occupied cost', 'Percent occupied income'], inplace =True)
# Out:
# C:\Users\eswan\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
median_2017_df.head()
# Out:
#          City State  Median household income (dollars)  Monthly cost  \
# 0   abbeville    la                              41082           514
# 1   abbeville    sc                              22898           549
# 2  abbotsford    wi                              42043           608
# 3    aberdeen    ms                              29317           578
# 4    aberdeen    sd                              47342           721
#
#   Owner occupied income Owner occupied cost renter occupied income  \
# 0                 51168                 399                  23326
# 1                 32998                 572                  14408
# 2                 53068                 667                  28594
# 3                 44957                 622                  18199
# 4                 70839                 840                  30029
#
#   renter occupied cost
# 0                  643
# 1                  544
# 2                  576
# 3                  537
# 4                  641

# %%
median_2017_df.dtypes
# Out:
# City                                 object
# State                                object
# Median household income (dollars)     int64
# Monthly cost                          int64
# Owner occupied income                object
# Owner occupied cost                  object
# renter occupied income               object
# renter occupied cost                 object
# dtype: object

# %% [markdown]
# ### Drop missing data

# %%
median_2017_df.loc[median_2017_df['Owner occupied income'].str.contains('-'),:].count()
# Out:
# City                                 0
# State                                0
# Median household income (dollars)    0
# Monthly cost                         0
# Owner occupied income                0
# Owner occupied cost                  0
# renter occupied income               0
# renter occupied cost                 0
# dtype: int64

# %%
median_2017_df = median_2017_df.drop(median_2017_df[median_2017_df['Owner occupied income'].str.contains('-')].index)

# %%
median_2017_df = median_2017_df.drop(median_2017_df[median_2017_df['renter occupied income'].str.contains('-')].index)

# %%
median_2017_df = median_2017_df.drop(median_2017_df[median_2017_df['renter occupied cost'].str.contains('-')].index)

# %%
median_2017_df['Owner occupied income'] = pd.to_numeric(median_2017_df['Owner occupied income'])

median_2017_df['Owner occupied cost'] = pd.to_numeric(median_2017_df['Owner occupied cost'])

median_2017_df['renter occupied income'] = pd.to_numeric(median_2017_df['renter occupied income'])

median_2017_df['renter occupied cost'] = pd.to_numeric(median_2017_df['renter occupied cost'])

# %%
median_2017_df.dtypes
# Out:
# City                                 object
# State                                object
# Median household income (dollars)     int64
# Monthly cost                          int64
# Owner occupied income                 int64
# Owner occupied cost                   int64
# renter occupied income                int64
# renter occupied cost                  int64
# dtype: object

# %%
median_2017_df = median_2017_df.add_suffix('_2017')

# %%
median_2017_df.rename(columns={
    'City_2017': 'City',
    'State_2017': 'State'
    
    
}, inplace=True)

# %%
median_2017_df.columns = median_2017_df.columns.str.lower()

# %%
median_2017_df.to_csv('cleaned/income_2017', index=False)
