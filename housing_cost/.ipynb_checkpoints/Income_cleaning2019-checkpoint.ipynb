# %%
import pandas as pd

# %%
df_2019 = pd.read_csv('raw/ACSST1Y2019.S2503_data_with_overlays_2021-09-19T113948.csv', header=1)

# %%
df_2019.shape
# Out:
# (438, 554)

# %%
df_2019.head()
# Out:
#                id                               Geographic Area Name  \
# 0  400C100US00199  Aberdeen--Bel Air South--Bel Air North, MD Urb...
# 1  400C100US00280                  Abilene, TX Urbanized Area (2010)
# 2  400C100US00631  Aguadilla--Isabela--San Sebastián, PR Urbanize...
# 3  400C100US00766                    Akron, OH Urbanized Area (2010)
# 4  400C100US00901                   Albany, GA Urbanized Area (2010)
#
#    Estimate!!Occupied housing units!!Occupied housing units  \
# 0                                              84583
# 1                                              41855
# 2                                              93361
# 3                                             238015
# 4                                              31769
#
#    Margin of Error!!Occupied housing units!!Occupied housing units  \
# 0                                               1895
# 1                                               1684
# ...

# %%
#df_2017.drop([col for col in df_2017.columns if 'Median' not in col], axis = 1, inplace=True)

# %%
word = 'Median'
word2 = 'Margin'
cols_list = [m for m in df_2019.columns if word in m and word2 not in m]

# %%
cols_list.insert(0, 'Geographic Area Name')

# %%
len(cols_list)
# Out:
# 13

# %%
cols_list
# Out:
# ['Geographic Area Name',
#  'Estimate!!Occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)',
#  'Estimate!!Occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)',
#  'Estimate!!Percent occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)',
#  'Estimate!!Percent occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)',
#  'Estimate!!Owner-occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)',
#  'Estimate!!Owner-occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)',
# ...

# %%
median_2019_df = df_2019[cols_list]

# %%
median_2019_df.rename(columns={
    'Geographic Area Name': 'location',
    'Estimate!!Occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)': 'Median household income (dollars)',
    'Estimate!!Occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)': 'Monthly cost',
    'Estimate!!Percent occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)': 'Percent occupied income',
    'Estimate!!Percent occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)':'Percent Occupied cost',
    'Estimate!!Owner-occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)':'Owner occupied income',
    'Estimate!!Owner-occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)': 'Owner occupied cost',
    'Estimate!!Percent owner-occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)':'Percent owner occupied income',
    'Estimate!!Percent owner-occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)':'Percent owner occupied house cost',
    'Estimate!!Renter-occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)':'renter occupied income',
    'Estimate!!Renter-occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)': 'renter occupied cost',
    'Estimate!!Percent renter-occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)': 'percent renter occupied income',
    'Estimate!!Percent renter-occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)':'percent renter occupied monthly costs'
    
    
    
    
}, inplace=True)
# Out:
# C:\Users\eswan\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
median_2019_df.head()
# Out:
#                                             location  \
# 0  Aberdeen--Bel Air South--Bel Air North, MD Urb...
# 1                  Abilene, TX Urbanized Area (2010)
# 2  Aguadilla--Isabela--San Sebastián, PR Urbanize...
# 3                    Akron, OH Urbanized Area (2010)
# 4                   Albany, GA Urbanized Area (2010)
#
#    Median household income (dollars)  Monthly cost  Percent occupied income  \
# 0                              90166          1388                    90166
# 1                              51913           864                    51913
# 2                              16582           193                    16582
# 3                              51928           834                    51928
# 4                              38440           799                    38440
#
#    Percent Occupied cost  Owner occupied income  Owner occupied cost  \
# 0                   1388                 103767                 1463
# ...

# %%
median_2019_df[['city', 'state']] = median_2019_df['location'].str.split(',', expand=True)
# Out:
# C:\Users\eswan\anaconda3\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
median_2019_df.head()
# Out:
#                                             location  \
# 0  Aberdeen--Bel Air South--Bel Air North, MD Urb...
# 1                  Abilene, TX Urbanized Area (2010)
# 2  Aguadilla--Isabela--San Sebastián, PR Urbanize...
# 3                    Akron, OH Urbanized Area (2010)
# 4                   Albany, GA Urbanized Area (2010)
#
#    Median household income (dollars)  Monthly cost  Percent occupied income  \
# 0                              90166          1388                    90166
# 1                              51913           864                    51913
# 2                              16582           193                    16582
# 3                              51928           834                    51928
# 4                              38440           799                    38440
#
#    Percent Occupied cost  Owner occupied income  Owner occupied cost  \
# 0                   1388                 103767                 1463
# ...

# %%
median_2019_df['state'] = median_2019_df['state'].str.split(' ').str[1]
# Out:
# <ipython-input-22-a64b601cd3d7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   median_2019_df['state'] = median_2019_df['state'].str.split(' ').str[1]

# %%
median_2019_df.head()
# Out:
#                                             location  \
# 0  Aberdeen--Bel Air South--Bel Air North, MD Urb...
# 1                  Abilene, TX Urbanized Area (2010)
# 2  Aguadilla--Isabela--San Sebastián, PR Urbanize...
# 3                    Akron, OH Urbanized Area (2010)
# 4                   Albany, GA Urbanized Area (2010)
#
#    Median household income (dollars)  Monthly cost  Percent occupied income  \
# 0                              90166          1388                    90166
# 1                              51913           864                    51913
# 2                              16582           193                    16582
# 3                              51928           834                    51928
# 4                              38440           799                    38440
#
#    Percent Occupied cost  Owner occupied income  Owner occupied cost  \
# 0                   1388                 103767                 1463
# ...

# %%
median_2019_df.drop(columns = 'location', inplace=True)
# Out:
# C:\Users\eswan\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
median_2019_df.insert(0, 'State', median_2019_df['state'])

median_2019_df.insert(0, 'City', median_2019_df['city'])

# %%
median_2019_df.drop(columns = ['city', 'state'], inplace=True)

# %%
median_2019_df.head()
# Out:
#                                      City State  \
# 0  Aberdeen--Bel Air South--Bel Air North    MD
# 1                                 Abilene    TX
# 2       Aguadilla--Isabela--San Sebastián    PR
# 3                                   Akron    OH
# 4                                  Albany    GA
#
#    Median household income (dollars)  Monthly cost  Percent occupied income  \
# 0                              90166          1388                    90166
# 1                              51913           864                    51913
# 2                              16582           193                    16582
# 3                              51928           834                    51928
# 4                              38440           799                    38440
#
#    Percent Occupied cost  Owner occupied income  Owner occupied cost  \
# 0                   1388                 103767                 1463
# 1                    864                  69349                  820
# ...

# %%
median_2019_df['City'] = median_2019_df['City'].str.lower()
median_2019_df['State'] = median_2019_df['State'].str.lower()
# Out:
# <ipython-input-28-f94ac54b51a6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   median_2019_df['City'] = median_2019_df['City'].str.lower()
# <ipython-input-28-f94ac54b51a6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   median_2019_df['State'] = median_2019_df['State'].str.lower()

# %%
median_2019_df.head(15)
# Out:
#                                       City   State  \
# 0   aberdeen--bel air south--bel air north      md
# 1                                  abilene      tx
# 2        aguadilla--isabela--san sebastián      pr
# 3                                    akron      oh
# 4                                   albany      ga
# 5                                   albany      or
# 6                      albany--schenectady      ny
# 7                              albuquerque      nm
# 8                               alexandria      la
# 9                                allentown  pa--nj
# 10                                   alton  il--mo
# 11                                 altoona      pa
# 12                                amarillo      tx
# 13                                    ames      ia
# 14                               anchorage      ak
#
#     Median household income (dollars)  Monthly cost  Percent occupied income  \
# ...

# %%
median_2019_df.to_csv('cleaned/income_2019')
