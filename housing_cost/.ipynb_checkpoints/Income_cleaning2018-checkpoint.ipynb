# %%
import pandas as pd

# %%
df_2017 = pd.read_csv('raw/ACSST1Y2018.S2503_data_with_overlays_2021-09-19T113041.csv', header=1)

# %%
df_2017.shape
# Out:
# (438, 554)

# %%
df_2017.head()
# Out:
#                id                               Geographic Area Name  \
# 0  400C100US00199  Aberdeen--Bel Air South--Bel Air North, MD Urb...
# 1  400C100US00280                  Abilene, TX Urbanized Area (2010)
# 2  400C100US00631  Aguadilla--Isabela--San Sebastián, PR Urbanize...
# 3  400C100US00766                    Akron, OH Urbanized Area (2010)
# 4  400C100US00901                   Albany, GA Urbanized Area (2010)
#
#    Estimate!!Occupied housing units!!Occupied housing units  \
# 0                                              83218
# 1                                              41789
# 2                                             100173
# 3                                             235021
# 4                                              34489
#
#    Margin of Error!!Occupied housing units MOE!!Occupied housing units  \
# 0                                               1867
# 1                                               1618
# ...

# %%
#df_2017.drop([col for col in df_2017.columns if 'Median' not in col], axis = 1, inplace=True)

# %%
word = 'Median'
word2 = 'Margin'
cols_list = [m for m in df_2017.columns if word in m and word2 not in m]

# %%
cols_list.insert(0, 'Geographic Area Name')

# %%
len(cols_list)
# Out:
# 13

# %%
cols_list
# Out:
# ['Geographic Area Name',
#  'Estimate!!Occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)',
#  'Estimate!!Occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)',
#  'Estimate!!Percent occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)',
#  'Estimate!!Percent occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)',
#  'Estimate!!Owner-occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)',
#  'Estimate!!Owner-occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)',
# ...

# %%
#import re
#clean = []
#for t in cols_list:
#    clean.append(re.sub(r'^.*?Median', '', t))

# %%
median_2018_df = df_2017[cols_list]

# %%
median_2018_df.rename(columns={
    'Geographic Area Name': 'location',
    'Estimate!!Occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)': 'Median household income (dollars)',
    'Estimate!!Occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)': 'Monthly cost',
    'Estimate!!Percent occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)': 'Percent occupied income',
    'Estimate!!Percent occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)':'Percent Occupied cost',
    'Estimate!!Owner-occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)':'Owner occupied income',
    'Estimate!!Owner-occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)': 'Owner occupied cost',
    'Estimate!!Percent owner-occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)':'Percent owner occupied income',
    'Estimate!!Percent owner-occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)':'Percent owner occupied house cost',
    'Estimate!!Renter-occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)':'renter occupied income',
    'Estimate!!Renter-occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)': 'renter occupied cost',
    'Estimate!!Percent renter-occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)!!Median household income (dollars)': 'percent renter occupied income',
    'Estimate!!Percent renter-occupied housing units!!Occupied housing units!!MONTHLY HOUSING COSTS!!Median (dollars)':'percent renter occupied monthly costs'
    
    
    
    
}, inplace=True)
# Out:
# C:\Users\eswan\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
median_2018_df.head()
# Out:
#                                             location  \
# 0  Aberdeen--Bel Air South--Bel Air North, MD Urb...
# 1                  Abilene, TX Urbanized Area (2010)
# 2  Aguadilla--Isabela--San Sebastián, PR Urbanize...
# 3                    Akron, OH Urbanized Area (2010)
# 4                   Albany, GA Urbanized Area (2010)
#
#    Median household income (dollars)  Monthly cost  Percent occupied income  \
# 0                              86876          1374                    86876
# 1                              46387           891                    46387
# 2                              17234           231                    17234
# 3                              53755           836                    53755
# 4                              40667           758                    40667
#
#    Percent Occupied cost  Owner occupied income  Owner occupied cost  \
# 0                   1374                  98033                 1465
# ...

# %%
median_2018_df[['city', 'state']] = median_2018_df['location'].str.split(',', expand=True)
# Out:
# C:\Users\eswan\anaconda3\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
median_2018_df.head()
# Out:
#                                             location  \
# 0  Aberdeen--Bel Air South--Bel Air North, MD Urb...
# 1                  Abilene, TX Urbanized Area (2010)
# 2  Aguadilla--Isabela--San Sebastián, PR Urbanize...
# 3                    Akron, OH Urbanized Area (2010)
# 4                   Albany, GA Urbanized Area (2010)
#
#    Median household income (dollars)  Monthly cost  Percent occupied income  \
# 0                              86876          1374                    86876
# 1                              46387           891                    46387
# 2                              17234           231                    17234
# 3                              53755           836                    53755
# 4                              40667           758                    40667
#
#    Percent Occupied cost  Owner occupied income  Owner occupied cost  \
# 0                   1374                  98033                 1465
# ...

# %%
median_2018_df['state'] = median_2018_df['state'].str.split(' ').str[1]
# Out:
# <ipython-input-17-c8c4d65c64fb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   median_2018_df['state'] = median_2018_df['state'].str.split(' ').str[1]

# %%
median_2018_df.head()
# Out:
#                                             location  \
# 0  Aberdeen--Bel Air South--Bel Air North, MD Urb...
# 1                  Abilene, TX Urbanized Area (2010)
# 2  Aguadilla--Isabela--San Sebastián, PR Urbanize...
# 3                    Akron, OH Urbanized Area (2010)
# 4                   Albany, GA Urbanized Area (2010)
#
#    Median household income (dollars)  Monthly cost  Percent occupied income  \
# 0                              86876          1374                    86876
# 1                              46387           891                    46387
# 2                              17234           231                    17234
# 3                              53755           836                    53755
# 4                              40667           758                    40667
#
#    Percent Occupied cost  Owner occupied income  Owner occupied cost  \
# 0                   1374                  98033                 1465
# ...

# %%
median_2018_df.drop(columns = 'location', inplace=True)
# Out:
# C:\Users\eswan\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
median_2018_df.insert(0, 'State', median_2018_df['state'])

median_2018_df.insert(0, 'City', median_2018_df['city'])

# %%
median_2018_df.drop(columns = ['city', 'state'], inplace=True)
# Out:
# C:\Users\eswan\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
median_2018_df.head()
# Out:
#                                      City State  \
# 0  Aberdeen--Bel Air South--Bel Air North    MD
# 1                                 Abilene    TX
# 2       Aguadilla--Isabela--San Sebastián    PR
# 3                                   Akron    OH
# 4                                  Albany    GA
#
#    Median household income (dollars)  Monthly cost  Percent occupied income  \
# 0                              86876          1374                    86876
# 1                              46387           891                    46387
# 2                              17234           231                    17234
# 3                              53755           836                    53755
# 4                              40667           758                    40667
#
#    Percent Occupied cost  Owner occupied income  Owner occupied cost  \
# 0                   1374                  98033                 1465
# 1                    891                  59643                  733
# ...

# %%
median_2018_df['City'] = median_2018_df['City'].str.lower()
median_2018_df['State'] = median_2018_df['State'].str.lower()
# Out:
# <ipython-input-26-ee8d42426562>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   median_2018_df['City'] = median_2018_df['City'].str.lower()
# <ipython-input-26-ee8d42426562>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   median_2018_df['State'] = median_2018_df['State'].str.lower()

# %%
median_2018_df.head(15)
# Out:
#                                       City   State  \
# 0   aberdeen--bel air south--bel air north      md
# 1                                  abilene      tx
# 2        aguadilla--isabela--san sebastián      pr
# 3                                    akron      oh
# 4                                   albany      ga
# 5                      albany--schenectady      ny
# 6                              albuquerque      nm
# 7                               alexandria      la
# 8                                allentown  pa--nj
# 9                                    alton  il--mo
# 10                                 altoona      pa
# 11                                amarillo      tx
# 12                                    ames      ia
# 13                               anchorage      ak
# 14                                anderson      in
#
#     Median household income (dollars)  Monthly cost  Percent occupied income  \
# ...

# %%
median_2018_df.to_csv('cleaned/income_2018')
