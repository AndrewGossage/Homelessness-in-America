# %%
#imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# seaborn plot styles

sns.set_style("dark")
sns.set_palette("deep")
plt.rcParams["axes.labelsize"] = 15
plt.rcParams["axes.titlesize"] = 20
myblue = '#0b5394'

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
data = pd.read_csv('./2014-2021-PIT-esimates-cleanish.csv', low_memory=False).drop(columns=['Unnamed: 0'])

# %%
data.head()
data.columns
data['year']
# Out:
#   CoC Number                                           CoC Name  \
# 0     AK-500                                      Anchorage CoC
# 1     AK-501                        Alaska Balance of State CoC
# 2     AL-500  Birmingham/Jefferson, St. Clair, Shelby Counti...
# 3     AL-501            Mobile City & County/Baldwin County CoC
# 4     AL-502                     Florence/Northwest Alabama CoC
#
#    Overall Homeless  Overall Homeless - Under 18  \
# 0            1023.0                        188.0
# 1             761.0                        209.0
# 2            1329.0                        262.0
# 3             598.0                        126.0
# 4             209.0                         50.0
#
#    Overall Homeless - Age 18 to 24  Overall Homeless - Over 24  \
# 0                            146.0                       689.0
# 1                             56.0                       496.0
# 2                             76.0                       991.0
# 3                             44.0                       428.0
# 4                              6.0                       153.0
#
#    Sheltered ES Homeless  Sheltered ES Homeless - Under 18  \
# 0                  665.0                              86.0
# 1                  474.0                             119.0
# 2                  387.0                              47.0
# 3                  287.0                              69.0
# 4                   38.0                               7.0
#
#    Sheltered ES Homeless - Age 18 to 24  Sheltered ES Homeless - Over 24  ...  \
# 0                                  88.0                            491.0  ...
# 1                                  30.0                            325.0  ...
# 2                                  27.0                            313.0  ...
# 3                                  24.0                            194.0  ...
# 4                                   1.0                             30.0  ...
#
#    Unsheltered Homeless Parenting Youth (Under 25) - Hispanic/Latino  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unsheltered Homeless Parenting Youth (Under 25) - White  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unsheltered Homeless Parenting Youth (Under 25) - Black or African American  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unsheltered Homeless Parenting Youth (Under 25) - Asian  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unsheltered Homeless Parenting Youth (Under 25) - American Indian or Alaska Native  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unsheltered Homeless Parenting Youth (Under 25) - Native Hawaiian or Other Pacific Islander  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unsheltered Homeless Parenting Youth (Under 25) - Multiple Races  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    CoC Category        City  State
# 0           NaN   anchorage     ak
# 1           NaN   anchorage     ak
# 2           NaN  birmingham     al
# 3           NaN      mobile     al
# 4           NaN    florence     al
#
# [5 rows x 545 columns]
# Index(['CoC Number', 'CoC Name', 'Overall Homeless',
#        'Overall Homeless - Under 18', 'Overall Homeless - Age 18 to 24',
#        'Overall Homeless - Over 24', 'Sheltered ES Homeless',
#        'Sheltered ES Homeless - Under 18',
#        'Sheltered ES Homeless - Age 18 to 24',
#        'Sheltered ES Homeless - Over 24',
#        ...
#        'Unsheltered Homeless Parenting Youth (Under 25) - Hispanic/Latino',
#        'Unsheltered Homeless Parenting Youth (Under 25) - White',
#        'Unsheltered Homeless Parenting Youth (Under 25) - Black or African American',
#        'Unsheltered Homeless Parenting Youth (Under 25) - Asian',
#        'Unsheltered Homeless Parenting Youth (Under 25) - American Indian or Alaska Native',
#        'Unsheltered Homeless Parenting Youth (Under 25) - Native Hawaiian or Other Pacific Islander',
#        'Unsheltered Homeless Parenting Youth (Under 25) - Multiple Races',
#        'CoC Category', 'City', 'State'],
#       dtype='object', length=545)
# 0       2014
# 1       2014
# 2       2014
# 3       2014
# 4       2014
#         ...
# 2738    2020
# 2739    2020
# 2740    2020
# 2741    2020
# 2742    2020
# Name: year, Length: 2743, dtype: int64

# %%
data.groupby(['City', 'State','year'])[['Overall Homeless']].sum()
# Out:
#                       Overall Homeless
# City      State year
# aberdeen  md    2014             223.0
#                 2015             210.0
#                 2016             179.0
#                 2017             189.0
#                 2018             190.0
# ...                                ...
# ypsilanti mi    2016             342.0
#                 2017             302.0
#                 2018             282.0
#                 2019             273.0
#                 2020             274.0
#
# [2566 rows x 1 columns]

# %% [markdown]
# ## Case study of groups 1 and 2 in Andrew's kmeans clusters
# - group 1: Atlanta, Houston, Madison
# - (Andrew's notebook had Baltimore, Indianapolis in group 1 but when I reran the code I got the cities above)
# - group 2: Austin, Jacksonville (Wasn't clear if Andrew's EDA was referring to Jacsonville, IL or Jacksonville, FL so doing the analysis for both)

# %%
#change in homeless numbers between 2014 and 2020

cities = [('atlanta', 'ga'), ('houston', 'tx'), ('madison', 'wi'), ('austin', 'tx'), ('jacksonville', 'fl'), ('jacksonville', 'il')];
fig, axes = plt.subplots(len(cities),1,figsize = (8,25));
plt.close()
for i, (city, state) in enumerate(cities):
    city_data = data[(data['City'] == city)&(data['State'] == state)][['Overall Homeless', 'year', 'Sheltered ES Homeless', 'Sheltered TH Homeless','Unsheltered Homeless']]
    axes[i] = city_data.groupby('year').sum().plot()
    axes[i].set_title(f'{city}, {state.upper()}');
    axes[i].set_ylabel('# homeless')
    axes[i].set_facecolor('black');
# Out:
# Text(0.5, 1.0, 'atlanta, GA')
# Text(0, 0.5, '# homeless')
# Text(0.5, 1.0, 'houston, TX')
# Text(0, 0.5, '# homeless')
# Text(0.5, 1.0, 'madison, WI')
# Text(0, 0.5, '# homeless')
# Text(0.5, 1.0, 'austin, TX')
# Text(0, 0.5, '# homeless')
# Text(0.5, 1.0, 'jacksonville, FL')
# Text(0, 0.5, '# homeless')
# Text(0.5, 1.0, 'jacksonville, IL')
# Text(0, 0.5, '# homeless')

# %% [markdown]
# ## A different question:
#
# - Which cities saw the highest increases/decreases in homeless numbers?

# %%
df = data.groupby(['City','State','year']).sum().reset_index()

#make a dataframe with change in homeless numbers for each city between 2014 -2021
start_year = 2014
end_year = 2020


df_start_year = df[df['year'] == start_year].drop(columns = ['year']).set_index(['City','State'])
df_end_year = df[df['year'] == end_year].drop(columns = ['year']).set_index(['City','State'])

# dropping cities for which we don't have data for both start_year and end_year

#df_end_year.subtract(df_start_year).dropna().sort_values(by = 'Overall Homeless')
df_end_year.subtract(df_start_year).dropna().sort_values(by = 'Overall Homeless').head(10)
df_end_year.subtract(df_start_year).dropna().sort_values(by = 'Overall Homeless').tail(10)
# Out:
#                        Overall Homeless  Overall Homeless - Under 18  \
# City            State
# cartersville    ga              -3228.0                       -670.0
# new port richey fl              -2458.0                       -698.0
# las vegas       nv              -2160.0                      -1233.0
# atlanta         ga              -1758.0                       -149.0
# lowell          ma              -1681.0                      -1012.0
# san juan        pr              -1681.0                       -288.0
# santa rosa      ca              -1521.0                       -244.0
# washington      dc              -1368.0                       -809.0
# houston         tx              -1334.0                       -419.0
# santa cruz      ca              -1273.0                       -125.0
#
#                        Overall Homeless - Age 18 to 24  \
# City            State
# cartersville    ga                              -319.0
# new port richey fl                              -406.0
# las vegas       nv                              -651.0
# atlanta         ga                              -186.0
# lowell          ma                              -258.0
# san juan        pr                              -130.0
# santa rosa      ca                              -568.0
# washington      dc                              -289.0
# houston         tx                              -195.0
# santa cruz      ca                              -285.0
#
#                        Overall Homeless - Over 24  Sheltered ES Homeless  \
# City            State
# cartersville    ga                        -2239.0                  143.0
# new port richey fl                        -1354.0                   40.0
# las vegas       nv                         -276.0                -1872.0
# atlanta         ga                        -1423.0                 -658.0
# lowell          ma                         -411.0                -1663.0
# san juan        pr                        -1263.0                 -176.0
# santa rosa      ca                         -709.0                  168.0
# washington      dc                         -270.0                -1228.0
# houston         tx                         -720.0                  673.0
# santa cruz      ca                         -863.0                   42.0
#
#                        Sheltered ES Homeless - Under 18  \
# City            State
# cartersville    ga                                -16.0
# new port richey fl                                 24.0
# las vegas       nv                               -400.0
# atlanta         ga                                 -4.0
# lowell          ma                               -882.0
# san juan        pr                                -17.0
# santa rosa      ca                                -10.0
# washington      dc                               -573.0
# houston         tx                                220.0
# santa cruz      ca                                  7.0
#
#                        Sheltered ES Homeless - Age 18 to 24  \
# City            State
# cartersville    ga                                      3.0
# new port richey fl                                     -3.0
# las vegas       nv                                   -120.0
# atlanta         ga                                    -71.0
# lowell          ma                                   -269.0
# san juan        pr                                    -24.0
# santa rosa      ca                                     11.0
# washington      dc                                   -325.0
# houston         tx                                     81.0
# santa cruz      ca                                     -5.0
#
#                        Sheltered ES Homeless - Over 24  Sheltered TH Homeless  \
# City            State
# cartersville    ga                               156.0                 -316.0
# new port richey fl                                19.0                   14.0
# las vegas       nv                             -1352.0                 -252.0
# atlanta         ga                              -583.0                 -639.0
# lowell          ma                              -512.0                 -319.0
# san juan        pr                              -135.0                 -630.0
# santa rosa      ca                               167.0                  -82.0
# washington      dc                              -330.0                 -397.0
# houston         tx                               372.0                -1384.0
# santa cruz      ca                                40.0                 -120.0
#
#                        Sheltered TH Homeless - Under 18  ...  \
# City            State                                    ...
# cartersville    ga                               -267.0  ...
# new port richey fl                                 20.0  ...
# las vegas       nv                               -117.0  ...
# atlanta         ga                               -101.0  ...
# lowell          ma                               -135.0  ...
# san juan        pr                               -149.0  ...
# santa rosa      ca                                 -1.0  ...
# washington      dc                               -237.0  ...
# houston         tx                               -578.0  ...
# santa cruz      ca                                -74.0  ...
#
#                        Unsheltered Homeless Parenting Youth (Under 25) - Transgender  \
# City            State
# cartersville    ga                                                   0.0
# new port richey fl                                                   0.0
# las vegas       nv                                                   0.0
# atlanta         ga                                                   0.0
# lowell          ma                                                   0.0
# san juan        pr                                                   1.0
# santa rosa      ca                                                   0.0
# washington      dc                                                   0.0
# houston         tx                                                   0.0
# santa cruz      ca                                                   0.0
#
#                        Unsheltered Homeless Parenting Youth (Under 25) - Gender Non-Conforming  \
# City            State
# cartersville    ga                                                   0.0
# new port richey fl                                                   0.0
# las vegas       nv                                                   0.0
# atlanta         ga                                                   0.0
# lowell          ma                                                   0.0
# san juan        pr                                                   0.0
# santa rosa      ca                                                   0.0
# washington      dc                                                   0.0
# houston         tx                                                   0.0
# santa cruz      ca                                                   0.0
#
#                        Unsheltered Homeless Parenting Youth (Under 25) - Non-Hispanic/Non-Latino  \
# City            State
# cartersville    ga                                                   3.0
# new port richey fl                                                   0.0
# las vegas       nv                                                   3.0
# atlanta         ga                                                   0.0
# lowell          ma                                                   0.0
# san juan        pr                                                   0.0
# santa rosa      ca                                                   1.0
# washington      dc                                                   0.0
# houston         tx                                                   0.0
# santa cruz      ca                                                   3.0
#
#                        Unsheltered Homeless Parenting Youth (Under 25) - Hispanic/Latino  \
# City            State
# cartersville    ga                                                   0.0
# new port richey fl                                                   0.0
# las vegas       nv                                                   1.0
# atlanta         ga                                                   0.0
# lowell          ma                                                   0.0
# san juan        pr                                                   1.0
# santa rosa      ca                                                   0.0
# washington      dc                                                   0.0
# houston         tx                                                   0.0
# santa cruz      ca                                                   5.0
#
#                        Unsheltered Homeless Parenting Youth (Under 25) - White  \
# City            State
# cartersville    ga                                                   0.0
# new port richey fl                                                   0.0
# las vegas       nv                                                   0.0
# atlanta         ga                                                   0.0
# lowell          ma                                                   0.0
# san juan        pr                                                   0.0
# santa rosa      ca                                                   1.0
# washington      dc                                                   0.0
# houston         tx                                                   0.0
# santa cruz      ca                                                   3.0
#
#                        Unsheltered Homeless Parenting Youth (Under 25) - Black or African American  \
# City            State
# cartersville    ga                                                   3.0
# new port richey fl                                                   0.0
# las vegas       nv                                                   2.0
# atlanta         ga                                                   0.0
# lowell          ma                                                   0.0
# san juan        pr                                                   1.0
# santa rosa      ca                                                   0.0
# washington      dc                                                   0.0
# houston         tx                                                   0.0
# santa cruz      ca                                                   0.0
#
#                        Unsheltered Homeless Parenting Youth (Under 25) - Asian  \
# City            State
# cartersville    ga                                                   0.0
# new port richey fl                                                   0.0
# las vegas       nv                                                   0.0
# atlanta         ga                                                   0.0
# lowell          ma                                                   0.0
# san juan        pr                                                   0.0
# santa rosa      ca                                                   0.0
# washington      dc                                                   0.0
# houston         tx                                                   0.0
# santa cruz      ca                                                   0.0
#
#                        Unsheltered Homeless Parenting Youth (Under 25) - American Indian or Alaska Native  \
# City            State
# cartersville    ga                                                   0.0
# new port richey fl                                                   0.0
# las vegas       nv                                                   0.0
# atlanta         ga                                                   0.0
# lowell          ma                                                   0.0
# san juan        pr                                                   0.0
# santa rosa      ca                                                   0.0
# washington      dc                                                   0.0
# houston         tx                                                   0.0
# santa cruz      ca                                                   4.0
#
#                        Unsheltered Homeless Parenting Youth (Under 25) - Native Hawaiian or Other Pacific Islander  \
# City            State
# cartersville    ga                                                   0.0
# new port richey fl                                                   0.0
# las vegas       nv                                                   0.0
# atlanta         ga                                                   0.0
# lowell          ma                                                   0.0
# san juan        pr                                                   0.0
# santa rosa      ca                                                   0.0
# washington      dc                                                   0.0
# houston         tx                                                   0.0
# santa cruz      ca                                                   0.0
#
#                        Unsheltered Homeless Parenting Youth (Under 25) - Multiple Races
# City            State
# cartersville    ga                                                   0.0
# new port richey fl                                                   0.0
# las vegas       nv                                                   2.0
# atlanta         ga                                                   0.0
# lowell          ma                                                   0.0
# san juan        pr                                                   0.0
# santa rosa      ca                                                   0.0
# washington      dc                                                   0.0
# houston         tx                                                   0.0
# santa cruz      ca                                                   1.0
#
# [10 rows x 539 columns]
#                      Overall Homeless  Overall Homeless - Under 18  \
# City          State
# mesa          az               1501.0                       -583.0
# corvallis     or               1520.0                        -21.0
# san francisco ca               1716.0                       -110.0
# san jose      ca               2038.0                         21.0
# renton,       wa               2802.0                        411.0
# sacramento    ca               3062.0                        226.0
# santa ana     ca               3145.0                        146.0
# oakland       ca               3865.0                       -323.0
# brooklyn      ny              10133.0                       -753.0
# los angeles   ca              29313.0                       3183.0
#
#                      Overall Homeless - Age 18 to 24  \
# City          State
# mesa          az                               -71.0
# corvallis     or                              -125.0
# san francisco ca                              -567.0
# san jose      ca                               614.0
# renton,       wa                               368.0
# sacramento    ca                               233.0
# santa ana     ca                               -60.0
# oakland       ca                               289.0
# brooklyn      ny                               198.0
# los angeles   ca                               164.0
#
#                      Overall Homeless - Over 24  Sheltered ES Homeless  \
# City          State
# mesa          az                         2155.0                 -386.0
# corvallis     or                         1666.0                 -430.0
# san francisco ca                         2393.0                  949.0
# san jose      ca                         1403.0                  426.0
# renton,       wa                         2023.0                 1179.0
# sacramento    ca                         2603.0                  351.0
# santa ana     ca                         3059.0                 1351.0
# oakland       ca                         3899.0                  394.0
# brooklyn      ny                        10688.0                11748.0
# los angeles   ca                        25966.0                 7863.0
#
#                      Sheltered ES Homeless - Under 18  \
# City          State
# mesa          az                                -35.0
# corvallis     or                                -52.0
# san francisco ca                                 31.0
# san jose      ca                                148.0
# renton,       wa                                237.0
# sacramento    ca                                 -8.0
# santa ana     ca                                114.0
# oakland       ca                                 17.0
# brooklyn      ny                               -181.0
# los angeles   ca                               3906.0
#
#                      Sheltered ES Homeless - Age 18 to 24  \
# City          State
# mesa          az                                    -55.0
# corvallis     or                                    -63.0
# san francisco ca                                     10.0
# san jose      ca                                     10.0
# renton,       wa                                     56.0
# sacramento    ca                                     53.0
# santa ana     ca                                     43.0
# oakland       ca                                    -14.0
# brooklyn      ny                                    170.0
# los angeles   ca                                    679.0
#
#                      Sheltered ES Homeless - Over 24  Sheltered TH Homeless  \
# City          State
# mesa          az                              -296.0                 -848.0
# corvallis     or                              -315.0                 -568.0
# san francisco ca                               908.0                  -44.0
# san jose      ca                               268.0                 -646.0
# renton,       wa                               886.0                -1258.0
# sacramento    ca                               306.0                 -403.0
# santa ana     ca                              1194.0                 -489.0
# oakland       ca                               391.0                 -531.0
# brooklyn      ny                             11759.0                -2060.0
# los angeles   ca                              3278.0                -2113.0
#
#                      Sheltered TH Homeless - Under 18  ...  \
# City          State                                    ...
# mesa          az                               -611.0  ...
# corvallis     or                               -282.0  ...
# san francisco ca                                -56.0  ...
# san jose      ca                               -310.0  ...
# renton,       wa                               -461.0  ...
# sacramento    ca                               -104.0  ...
# santa ana     ca                               -213.0  ...
# oakland       ca                               -257.0  ...
# brooklyn      ny                               -567.0  ...
# los angeles   ca                               -613.0  ...
#
#                      Unsheltered Homeless Parenting Youth (Under 25) - Transgender  \
# City          State
# mesa          az                                                   0.0
# corvallis     or                                                   0.0
# san francisco ca                                                   0.0
# san jose      ca                                                   0.0
# renton,       wa                                                   0.0
# sacramento    ca                                                   0.0
# santa ana     ca                                                   0.0
# oakland       ca                                                   0.0
# brooklyn      ny                                                   0.0
# los angeles   ca                                                   0.0
#
#                      Unsheltered Homeless Parenting Youth (Under 25) - Gender Non-Conforming  \
# City          State
# mesa          az                                                   0.0
# corvallis     or                                                   0.0
# san francisco ca                                                   0.0
# san jose      ca                                                   0.0
# renton,       wa                                                   0.0
# sacramento    ca                                                   0.0
# santa ana     ca                                                   0.0
# oakland       ca                                                   0.0
# brooklyn      ny                                                   0.0
# los angeles   ca                                                   2.0
#
#                      Unsheltered Homeless Parenting Youth (Under 25) - Non-Hispanic/Non-Latino  \
# City          State
# mesa          az                                                   2.0
# corvallis     or                                                  13.0
# san francisco ca                                                   8.0
# san jose      ca                                                  16.0
# renton,       wa                                                  13.0
# sacramento    ca                                                  27.0
# santa ana     ca                                                   0.0
# oakland       ca                                                   1.0
# brooklyn      ny                                                   0.0
# los angeles   ca                                                  50.0
#
#                      Unsheltered Homeless Parenting Youth (Under 25) - Hispanic/Latino  \
# City          State
# mesa          az                                                   3.0
# corvallis     or                                                   1.0
# san francisco ca                                                   5.0
# san jose      ca                                                   9.0
# renton,       wa                                                  37.0
# sacramento    ca                                                   6.0
# santa ana     ca                                                   2.0
# oakland       ca                                                   0.0
# brooklyn      ny                                                   0.0
# los angeles   ca                                                 118.0
#
#                      Unsheltered Homeless Parenting Youth (Under 25) - White  \
# City          State
# mesa          az                                                   3.0
# corvallis     or                                                  13.0
# san francisco ca                                                   2.0
# san jose      ca                                                   8.0
# renton,       wa                                                  22.0
# sacramento    ca                                                   6.0
# santa ana     ca                                                   1.0
# oakland       ca                                                   0.0
# brooklyn      ny                                                   0.0
# los angeles   ca                                                  44.0
#
#                      Unsheltered Homeless Parenting Youth (Under 25) - Black or African American  \
# City          State
# mesa          az                                                   2.0
# corvallis     or                                                   0.0
# san francisco ca                                                   5.0
# san jose      ca                                                   7.0
# renton,       wa                                                   7.0
# sacramento    ca                                                  20.0
# santa ana     ca                                                   0.0
# oakland       ca                                                   1.0
# brooklyn      ny                                                   0.0
# los angeles   ca                                                 124.0
#
#                      Unsheltered Homeless Parenting Youth (Under 25) - Asian  \
# City          State
# mesa          az                                                   0.0
# corvallis     or                                                   0.0
# san francisco ca                                                   0.0
# san jose      ca                                                   1.0
# renton,       wa                                                   0.0
# sacramento    ca                                                   0.0
# santa ana     ca                                                   1.0
# oakland       ca                                                   0.0
# brooklyn      ny                                                   0.0
# los angeles   ca                                                   0.0
#
#                      Unsheltered Homeless Parenting Youth (Under 25) - American Indian or Alaska Native  \
# City          State
# mesa          az                                                   0.0
# corvallis     or                                                   0.0
# san francisco ca                                                   1.0
# san jose      ca                                                   3.0
# renton,       wa                                                  16.0
# sacramento    ca                                                   0.0
# santa ana     ca                                                   0.0
# oakland       ca                                                   0.0
# brooklyn      ny                                                   0.0
# los angeles   ca                                                   0.0
#
#                      Unsheltered Homeless Parenting Youth (Under 25) - Native Hawaiian or Other Pacific Islander  \
# City          State
# mesa          az                                                   0.0
# corvallis     or                                                   0.0
# san francisco ca                                                   1.0
# san jose      ca                                                   1.0
# renton,       wa                                                   2.0
# sacramento    ca                                                   0.0
# santa ana     ca                                                   0.0
# oakland       ca                                                   0.0
# brooklyn      ny                                                   0.0
# los angeles   ca                                                   0.0
#
#                      Unsheltered Homeless Parenting Youth (Under 25) - Multiple Races
# City          State
# mesa          az                                                   0.0
# corvallis     or                                                   1.0
# san francisco ca                                                   4.0
# san jose      ca                                                   5.0
# renton,       wa                                                   3.0
# sacramento    ca                                                   7.0
# santa ana     ca                                                   0.0
# oakland       ca                                                   0.0
# brooklyn      ny                                                   0.0
# los angeles   ca                                                   0.0
#
# [10 rows x 539 columns]

# %%
#Distribution of the homeless numbers
data[data['year'] == 2020].groupby(['City','State']).sum().describe()
# Out:
#        Overall Homeless  Overall Homeless - Under 18  \
# count        370.000000                   370.000000
# mean        1552.910811                   284.127027
# std         5386.604891                  1322.763989
# min           21.000000                     0.000000
# 25%          301.750000                    51.500000
# 50%          607.500000                   107.500000
# 75%         1395.500000                   197.750000
# max        77943.000000                 23940.000000
#
#        Overall Homeless - Age 18 to 24  Overall Homeless - Over 24  \
# count                       370.000000                  370.000000
# mean                        120.794595                 1147.989189
# std                         451.899083                 3779.341668
# min                           0.000000                   14.000000
# 25%                          18.000000                  218.250000
# 50%                          42.500000                  434.000000
# 75%                          99.000000                 1055.750000
# max                        7163.000000                52034.000000
#
#        Sheltered ES Homeless  Sheltered ES Homeless - Under 18  \
# count             370.000000                        370.000000
# mean              750.743243                        202.554054
# std              3786.950488                       1278.060662
# min                 2.000000                          0.000000
# 25%               145.000000                         29.000000
# 50%               251.500000                         59.000000
# 75%               614.750000                        133.000000
# max             70875.000000                      23859.000000
#
#        Sheltered ES Homeless - Age 18 to 24  Sheltered ES Homeless - Over 24  \
# count                            370.000000                       370.000000
# mean                              52.775676                       495.413514
# std                              333.105688                      2183.980574
# min                                0.000000                         0.000000
# 25%                                8.000000                       101.000000
# 50%                               16.000000                       190.000000
# 75%                               40.000000                       441.750000
# max                             6288.000000                     40728.000000
#
#        Sheltered TH Homeless  Sheltered TH Homeless - Under 18  ...  \
# count             370.000000                        370.000000  ...
# mean              193.602703                         53.924324  ...
# std               334.413237                         91.650093  ...
# min                 0.000000                          0.000000  ...
# 25%                35.000000                          8.000000  ...
# 50%                99.000000                         27.000000  ...
# 75%               213.750000                         61.000000  ...
# max              3455.000000                        850.000000  ...
#
#        Unsheltered Homeless Parenting Youth (Under 25) - Transgender  \
# count                                         370.000000
# mean                                            0.005405
# std                                             0.073422
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Unsheltered Homeless Parenting Youth (Under 25) - Gender Non-Conforming  \
# count                                         370.000000
# mean                                            0.005405
# std                                             0.103975
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             2.000000
#
#        Unsheltered Homeless Parenting Youth (Under 25) - Non-Hispanic/Non-Latino  \
# count                                         370.000000
# mean                                            0.883784
# std                                             3.500678
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                            50.000000
#
#        Unsheltered Homeless Parenting Youth (Under 25) - Hispanic/Latino  \
# count                                         370.000000
# mean                                            0.602703
# std                                             6.473753
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                           118.000000
#
#        Unsheltered Homeless Parenting Youth (Under 25) - White  \
# count                                         370.000000
# mean                                            0.627027
# std                                             2.946924
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                            44.000000
#
#        Unsheltered Homeless Parenting Youth (Under 25) - Black or African American  \
# count                                         370.000000
# mean                                            0.610811
# std                                             6.566309
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                           124.000000
#
#        Unsheltered Homeless Parenting Youth (Under 25) - Asian  \
# count                                         370.000000
# mean                                            0.005405
# std                                             0.073422
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Unsheltered Homeless Parenting Youth (Under 25) - American Indian or Alaska Native  \
# count                                         370.000000
# mean                                            0.102703
# std                                             0.928468
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                            16.000000
#
#        Unsheltered Homeless Parenting Youth (Under 25) - Native Hawaiian or Other Pacific Islander  \
# count                                         370.000000
# mean                                            0.029730
# std                                             0.236695
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             3.000000
#
#        Unsheltered Homeless Parenting Youth (Under 25) - Multiple Races
# count                                         370.000000
# mean                                            0.110811
# std                                             0.603640
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             7.000000
#
# [8 rows x 540 columns]

# %%
#which CoC has the highest homeless numbers?
data.sort_values(by = ['Overall Homeless'], ascending = False).head()
# Out:
#      CoC Number           CoC Name  Overall Homeless  \
# 1843     NY-600  New York City CoC           78676.0
# 2236     NY-600  New York City CoC           78604.0
# 2628     NY-600  New York City CoC           77943.0
# 1450     NY-600  New York City CoC           76501.0
# 666      NY-600  New York City CoC           75323.0
#
#       Overall Homeless - Under 18  Overall Homeless - Age 18 to 24  \
# 1843                      25747.0                           7571.0
# 2236                      24725.0                           7316.0
# 2628                      23940.0                           7163.0
# 1450                      25830.0                           7813.0
# 666                       26860.0                           7392.0
#
#       Overall Homeless - Over 24  Sheltered ES Homeless  \
# 1843                     45358.0                72187.0
# 2236                     46563.0                72123.0
# 2628                     46840.0                70875.0
# 1450                     42858.0                69605.0
# 666                      41071.0                67378.0
#
#       Sheltered ES Homeless - Under 18  Sheltered ES Homeless - Age 18 to 24  \
# 1843                           25726.0                                6921.0
# 2236                           24702.0                                6668.0
# 2628                           23859.0                                6288.0
# 1450                           25713.0                                7093.0
# 666                            26242.0                                6782.0
#
#       Sheltered ES Homeless - Over 24  ...  \
# 1843                          39540.0  ...
# 2236                          40753.0  ...
# 2628                          40728.0  ...
# 1450                          36799.0  ...
# 666                           34354.0  ...
#
#       Unsheltered Homeless Parenting Youth (Under 25) - Hispanic/Latino  \
# 1843                                                0.0
# 2236                                                0.0
# 2628                                                0.0
# 1450                                                0.0
# 666                                                 NaN
#
#       Unsheltered Homeless Parenting Youth (Under 25) - White  \
# 1843                                                0.0
# 2236                                                0.0
# 2628                                                0.0
# 1450                                                0.0
# 666                                                 NaN
#
#       Unsheltered Homeless Parenting Youth (Under 25) - Black or African American  \
# 1843                                                0.0
# 2236                                                0.0
# 2628                                                0.0
# 1450                                                0.0
# 666                                                 NaN
#
#       Unsheltered Homeless Parenting Youth (Under 25) - Asian  \
# 1843                                                0.0
# 2236                                                0.0
# 2628                                                0.0
# 1450                                                0.0
# 666                                                 NaN
#
#       Unsheltered Homeless Parenting Youth (Under 25) - American Indian or Alaska Native  \
# 1843                                                0.0
# 2236                                                0.0
# 2628                                                0.0
# 1450                                                0.0
# 666                                                 NaN
#
#       Unsheltered Homeless Parenting Youth (Under 25) - Native Hawaiian or Other Pacific Islander  \
# 1843                                                0.0
# 2236                                                0.0
# 2628                                                0.0
# 1450                                                0.0
# 666                                                 NaN
#
#       Unsheltered Homeless Parenting Youth (Under 25) - Multiple Races  \
# 1843                                                0.0
# 2236                                                0.0
# 2628                                                0.0
# 1450                                                0.0
# 666                                                 NaN
#
#         CoC Category      City  State
# 1843             NaN  brooklyn     ny
# 2236             NaN  brooklyn     ny
# 2628  Major City CoC  brooklyn     ny
# 1450             NaN  brooklyn     ny
# 666              NaN  brooklyn     ny
#
# [5 rows x 545 columns]

# %%
#Normalize by population
 
#import population info

other_data = pd.read_csv('~/GA/Project5/Project5/data/weather-population/city_data.csv')

# %%
other_data[['city', 'usps']]
# Out:
#             city usps
# 0         Albany  NaN
# 1    Albuquerque   NM
# 2      Anchorage   AK
# 3      Asheville  NaN
# 4        Atlanta   GA
# ..           ...  ...
# 98         Tulsa   OK
# 99    Vero Beach  NaN
# 100   Washington   DC
# 101      Wichita   KS
# 102   Wilmington  NaN
#
# [103 rows x 2 columns]

# %% [markdown]
# ## Change in homeless numbers vs Temporary/permanent housing solutions
#
# - Temporary housing programs:
#     - ES (Emergency Shelters), TH (Transitional Housing), SH (Safe haven)
# - Permanent housing programs:
#     - RRH (Rapid re-housing), PSH (Permanent supportive housing), OPH (Other permanent housing)
#
# [source](#https://homelessstrategy.com/how-many-temporary-and-permanent-housing-beds-for-homeless-persons-are-there-in-california-what-is-the-bed-coverage-rate-in-homeless-management-information-system-hmis/)

# %%
# Reading in HIC data

data_2 = pd.read_csv('./2014-2021-HIC-cleanish.csv', low_memory=False).drop(columns=['Unnamed: 0'])

# %%
data_2.head()
data_2.columns
data_2['year']
# Out:
#   CoC Number  Total Year-Round Beds (ES, TH, SH)  \
# 0     AK-500                               988.0
# 1     AK-501                               826.0
# 2     AL-500                              1065.0
# 3     AL-501                               537.0
# 4     AL-502                               266.0
#
#    Total Non-DV Year-Round Beds (ES, TH, SH)  \
# 0                                      912.0
# 1                                      470.0
# 2                                      978.0
# 3                                      456.0
# 4                                      188.0
#
#    Total HMIS Year-Round Beds (ES, TH, SH)  \
# 0                                    648.0
# 1                                    383.0
# 2                                    823.0
# 3                                    348.0
# 4                                     34.0
#
#   HMIS Participation Rate for Year-Round Beds (ES, TH, SH)  \
# 0                                             0.6559
# 1                                             0.4637
# 2                                             0.7728
# 3                                              0.648
# 4                                             0.1278
#
#    Total Year-Round Beds (ES)  Total Year-Round Beds (TH)  \
# 0                       606.0                       382.0
# 1                       583.0                       243.0
# 2                       400.0                       631.0
# 3                       344.0                       193.0
# 4                        82.0                       184.0
#
#    Total Year-Round Beds (SH)  \
# 0                         0.0
# 1                         0.0
# 2                        34.0
# 3                         0.0
# 4                         0.0
#
#    Total Units for Households with Children (ES, TH, SH)  \
# 0                                               86.0
# 1                                              100.0
# 2                                              127.0
# 3                                               75.0
# 4                                               42.0
#
#    Total Beds for Households with Children (ES, TH, SH)  ...  \
# 0                                              330.0     ...
# 1                                              316.0     ...
# 2                                              409.0     ...
# 3                                              213.0     ...
# 4                                              143.0     ...
#
#    Dedicated Veteran Beds (RRH)  Dedicated Youth Beds (RRH)  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#    Dedicated Veteran Beds (PSH)  Dedicated Youth Beds (PSH)  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#    Dedicated Chronically Homeless Beds (PSH) Dedicated Veteran Beds (OPH)  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
#
#    Dedicated Youth Beds (OPH)  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
#                                             CoC Name        City  State
# 0                                      Anchorage CoC   anchorage     ak
# 1                        Alaska Balance of State CoC   anchorage     ak
# 2  Birmingham/Jefferson, St. Clair, Shelby Counti...  birmingham     al
# 3            Mobile City & County/Baldwin County CoC      mobile     al
# 4                     Florence/Northwest Alabama CoC    florence     al
#
# [5 rows x 97 columns]
# Index(['CoC Number', 'Total Year-Round Beds (ES, TH, SH)',
#        'Total Non-DV Year-Round Beds (ES, TH, SH)',
#        'Total HMIS Year-Round Beds (ES, TH, SH)',
#        'HMIS Participation Rate for Year-Round Beds (ES, TH, SH)',
#        'Total Year-Round Beds (ES)', 'Total Year-Round Beds (TH)',
#        'Total Year-Round Beds (SH)',
#        'Total Units for Households with Children (ES, TH, SH)',
#        'Total Beds for Households with Children (ES, TH, SH)',
#        'Total Beds for Households without Children (ES, TH, SH)',
#        'Total Beds for Households with only Children (ES, TH, SH)',
#        'Total Year-Round Beds (ES).1', 'Total Non-DV Year-Round Beds (ES)',
#        'Total HMIS Year-Round Beds (ES)',
#        'HMIS Participation Rate for Year-Round Beds (ES)',
#        'Total Seasonal Beds (ES)', 'Total Overflow Beds (ES)',
#        'Total Units for Households with Children (ES)',
#        'Total Beds for Households with Children (ES)',
#        'Total Beds for Households without Children (ES)',
#        'Total Beds for Households with only Children (ES)',
#        'Total Year-Round Beds (TH).1', 'Total Non-DV Year-Round Beds (TH)',
#        'Total HMIS Year-Round Beds (TH)',
#        'HMIS Participation Rate for Year-Round Beds (TH)',
#        'Total Units for Households with Children (TH)',
#        'Total Beds for Households with Children (TH)',
#        'Total Beds for Households without Children (TH)',
#        'Total Beds for Households with only Children (TH)',
#        'Total Year-Round Beds (SH).1', 'Total Non-DV Year-Round Beds (SH)',
#        'Total HMIS Year-Round Beds (SH)',
#        'HMIS Participation Rate for Year-Round Beds (SH)',
#        'Total Units for Households with Children (SH)',
#        'Total Beds for Households with Children (SH)',
#        'Total Beds for Households without Children (SH)',
#        'Total Beds for Households with only Children (SH)',
#        'Total Year-Round Beds (RRH & DEM)',
#        'Total Non-DV Year-Round Beds (RRH & DEM)',
#        'Total HMIS Year-Round Beds (RRH & DEM)',
#        'HMIS Participation Rate for Year-Round Beds (RRH & DEM)',
#        'Total Units for Households with Children (RRH & DEM)',
#        'Total Beds for Households with Children (RRH & DEM)',
#        'Total Beds for Households without Children (RRH & DEM)',
#        'Total Beds for Households with only Children (RRH & DEM)',
#        'Total Year-Round Beds (RRH)', 'Total Non-DV Year-Round Beds (RRH)',
#        'Total HMIS Year-Round Beds (RRH)',
#        'HMIS Participation Rate for Year-Round Beds (RRH)',
#        'Total Units for Households with Children (RRH)',
#        'Total Beds for Households with Children (RRH)',
#        'Total Beds for Households without Children (RRH)',
#        'Total Beds for Households with only Children (RRH)',
#        'Total Year-Round Beds (DEM)', 'Total Non-DV Year-Round Beds (DEM)',
#        'Total HMIS Year-Round Beds (DEM)',
#        'HMIS Participation Rate for Year-Round Beds (DEM)',
#        'Total Units for Households with Children (DEM)',
#        'Total Beds for Households with Children (DEM)',
#        'Total Beds for Households without Children (DEM)',
#        'Total Beds for Households with only Children (DEM)',
#        'Total Year-Round Beds (PSH)', 'Total Non-DV Year-Round Beds (PSH)',
#        'Total HMIS Year-Round Beds (PSH)',
#        'HMIS Participation Rate for Year-Round Beds (PSH)',
#        'Total Units for Households with Children (PSH)',
#        'Total Beds for Households with Children (PSH)',
#        'Total Beds for Households without Children (PSH)',
#        'Total Beds for Households with only Children (PSH)',
#        'Total Year-Round Beds (OPH)', 'Total Non-DV Year-Round Beds (OPH)',
#        'Total HMIS Year-Round Beds (OPH)',
#        'HMIS Participation Rate for Year-Round Beds (OPH)',
#        'Total Units for Households with Children (OPH)',
#        'Total Beds for Households with Children (OPH)',
#        'Total Beds for Households without Children (OPH)',
#        'Total Beds for Households with only Children (OPH)', 'year',
#        'Dedicated Veteran Beds (ES, TH, SH)',
#        'Dedicated Youth Beds (ES, TH, SH)', 'Dedicated Veteran Beds (ES)',
#        'Dedicated Youth Beds (ES)', 'Dedicated Veteran Beds (TH)',
#        'Dedicated Youth Beds (TH)', 'Dedicated Veteran Beds (SH)',
#        'Dedicated Youth Beds (SH)', 'Dedicated Veteran Beds (RRH)',
#        'Dedicated Youth Beds (RRH)', 'Dedicated Veteran Beds (PSH)',
#        'Dedicated Youth Beds (PSH)',
#        'Dedicated Chronically Homeless Beds (PSH)',
#        'Dedicated Veteran Beds (OPH)', 'Dedicated Youth Beds (OPH)',
#        'CoC Name', 'City', 'State'],
#       dtype='object')
# 0       2014
# 1       2014
# 2       2014
# 3       2014
# 4       2014
#         ...
# 2809    2020
# 2810    2020
# 2811    2020
# 2812    2020
# 2813    2020
# Name: year, Length: 2814, dtype: int64

# %%
data_2.groupby(['City', 'State','year'])[['Total Year-Round Beds (ES, TH, SH)','Total Year-Round Beds (RRH)','Total Year-Round Beds (PSH)', 'Total Year-Round Beds (OPH)']].sum()
# Out:
#                       Total Year-Round Beds (ES, TH, SH)  \
# City      State year
# aberdeen  md    2014                               154.0
#                 2015                               149.0
#                 2016                               175.0
#                 2017                               143.0
#                 2018                               161.0
# ...                                                  ...
# ypsilanti mi    2016                               265.0
#                 2017                               227.0
#                 2018                               235.0
#                 2019                               228.0
#                 2020                               287.0
#
#                       Total Year-Round Beds (RRH)  \
# City      State year
# aberdeen  md    2014                          0.0
#                 2015                          0.0
#                 2016                          0.0
#                 2017                          0.0
#                 2018                         35.0
# ...                                           ...
# ypsilanti mi    2016                        295.0
#                 2017                        270.0
#                 2018                        256.0
#                 2019                        266.0
#                 2020                        264.0
#
#                       Total Year-Round Beds (PSH)  Total Year-Round Beds (OPH)
# City      State year
# aberdeen  md    2014                        118.0                          0.0
#                 2015                        130.0                          0.0
#                 2016                        154.0                          0.0
#                 2017                        139.0                          0.0
#                 2018                        159.0                          0.0
# ...                                           ...                          ...
# ypsilanti mi    2016                        885.0                        549.0
#                 2017                        843.0                        549.0
#                 2018                        869.0                          0.0
#                 2019                       1021.0                          0.0
#                 2020                        623.0                          0.0
#
# [2562 rows x 4 columns]

# %%
#change in homeless numbers between 2014 and 2020

cities = [('atlanta', 'ga'), ('houston', 'tx'), ('madison', 'wi'), ('austin', 'tx'), ('jacksonville', 'fl'), ('jacksonville', 'il')];
fig, axes = plt.subplots(len(cities),2,figsize = (20,35));

for i, (city, state) in enumerate(cities):
    city_data = data[(data['City'] == city)&(data['State'] == state)][['Overall Homeless', 'year', 'Sheltered ES Homeless', 'Sheltered TH Homeless','Unsheltered Homeless']]
    sns.lineplot(ax = axes[i][0], data = city_data.groupby('year').sum())
    axes[i][0].set_title(f'{city}, {state.upper()}');
    axes[i][0].set_ylabel('# homeless')
    axes[i][0].set_facecolor('black');

    df = data_2[(data_2['City'] == city)&(data_2['State'] == state)][['year', 'Total Year-Round Beds (ES, TH, SH)','Total Year-Round Beds (RRH)','Total Year-Round Beds (PSH)', 'Total Year-Round Beds (OPH)']]
    city_HIC_data = df[['year']].copy()
    city_HIC_data['# temporary housing units'] = df['Total Year-Round Beds (ES, TH, SH)'].copy()
    city_HIC_data['# permanent housing units'] = df[['Total Year-Round Beds (RRH)','Total Year-Round Beds (PSH)', 'Total Year-Round Beds (OPH)']].sum(axis=1).copy()    
    sns.lineplot(ax = axes[i][1], data = city_HIC_data.groupby('year').sum());
    axes[i][1].set_title(f'{city}, {state.upper()}');
    axes[i][1].set_ylabel('HIC')
    axes[i][1].set_facecolor('black');
# Out:
# <AxesSubplot:xlabel='year'>
# Text(0.5, 1.0, 'atlanta, GA')
# Text(0, 0.5, '# homeless')
# <AxesSubplot:xlabel='year'>
# Text(0.5, 1.0, 'atlanta, GA')
# Text(0, 0.5, 'HIC')
# <AxesSubplot:xlabel='year'>
# Text(0.5, 1.0, 'houston, TX')
# Text(0, 0.5, '# homeless')
# <AxesSubplot:xlabel='year'>
# Text(0.5, 1.0, 'houston, TX')
# Text(0, 0.5, 'HIC')
# <AxesSubplot:xlabel='year'>
# Text(0.5, 1.0, 'madison, WI')
# Text(0, 0.5, '# homeless')
# <AxesSubplot:xlabel='year'>
# Text(0.5, 1.0, 'madison, WI')
# Text(0, 0.5, 'HIC')
# <AxesSubplot:xlabel='year'>
# Text(0.5, 1.0, 'austin, TX')
# Text(0, 0.5, '# homeless')
# <AxesSubplot:xlabel='year'>
# Text(0.5, 1.0, 'austin, TX')
# Text(0, 0.5, 'HIC')
# <AxesSubplot:xlabel='year'>
# Text(0.5, 1.0, 'jacksonville, FL')
# Text(0, 0.5, '# homeless')
# <AxesSubplot:xlabel='year'>
# Text(0.5, 1.0, 'jacksonville, FL')
# Text(0, 0.5, 'HIC')
# <AxesSubplot:xlabel='year'>
# Text(0.5, 1.0, 'jacksonville, IL')
# Text(0, 0.5, '# homeless')
# <AxesSubplot:xlabel='year'>
# Text(0.5, 1.0, 'jacksonville, IL')
# Text(0, 0.5, 'HIC')

# %%
city_HIC_data
# Out:
#       Total Year-Round Beds (ES, TH, SH)  Total Year-Round Beds (RRH)  \
# 98                                3747.0                        149.0
# 100                                365.0                         16.0
# 513                               3609.0                        197.0
# 515                                422.0                          0.0
# 919                               3384.0                        519.0
# 921                                422.0                          0.0
# 1322                              3419.0                        177.0
# 1324                               264.0                         15.0
# 1722                              2821.0                        652.0
# 1724                               141.0                         15.0
# 2120                              2729.0                        681.0
# 2122                               564.0                        282.0
# 2517                              2731.0                        710.0
# 2519                               247.0                         71.0
#
#       Total Year-Round Beds (PSH)  Total Year-Round Beds (OPH)
# 98                         1677.0                          0.0
# 100                         336.0                          0.0
# 513                        2247.0                          0.0
# 515                         509.0                          0.0
# 919                        2325.0                          0.0
# 921                         567.0                          0.0
# 1322                       1941.0                          0.0
# 1324                        299.0                          5.0
# 1722                       1898.0                          0.0
# 1724                        230.0                          0.0
# 2120                       1833.0                        226.0
# 2122                        215.0                          0.0
# 2517                       1743.0                        222.0
# 2519                        376.0                          0.0

# %%
# data_2[data_2['City'] == 'sacramento']
# data[data['City'] == 'sacramento']
data_2[data_2['City'] == 'tulsa']

#Dallas not in our data
# Out:
#      CoC Number  Total Year-Round Beds (ES, TH, SH)  \
# 313      OK-500                               235.0
# 314      OK-501                               874.0
# 723      OK-500                               245.0
# 724      OK-501                               826.0
# 1126     OK-500                               208.0
# 1127     OK-501                               818.0
# 1527     OK-500                               213.0
# 1528     OK-501                               848.0
# 1926     OK-500                               208.0
# 1927     OK-501                               727.0
# 2324     OK-500                               158.0
# 2325     OK-501                               730.0
# 2715     OK-500                               201.0
# 2716     OK-501                               831.0
#
#       Total Non-DV Year-Round Beds (ES, TH, SH)  \
# 313                                       124.0
# 314                                       740.0
# 723                                       134.0
# 724                                       692.0
# 1126                                      118.0
# 1127                                      684.0
# 1527                                      121.0
# 1528                                      714.0
# 1926                                      114.0
# 1927                                      593.0
# 2324                                      105.0
# 2325                                      585.0
# 2715                                      145.0
# 2716                                      686.0
#
#       Total HMIS Year-Round Beds (ES, TH, SH)  \
# 313                                      91.0
# 314                                     709.0
# 723                                      95.0
# 724                                     664.0
# 1126                                     74.0
# 1127                                    656.0
# 1527                                     77.0
# 1528                                    666.0
# 1926                                     70.0
# 1927                                    548.0
# 2324                                     68.0
# 2325                                    531.0
# 2715                                     98.0
# 2716                                    674.0
#
#      HMIS Participation Rate for Year-Round Beds (ES, TH, SH)  \
# 313                                              0.3872
# 314                                              0.8112
# 723                                              0.3878
# 724                                              0.8039
# 1126                                             0.3558
# 1127                                              0.802
# 1527                                             0.3615
# 1528                                             0.7854
# 1926                                             0.3365
# 1927                                             0.7538
# 2324                                             0.4304
# 2325                                             0.7274
# 2715                                             0.4876
# 2716                                             0.8111
#
#       Total Year-Round Beds (ES)  Total Year-Round Beds (TH)  \
# 313                        127.0                       108.0
# 314                        528.0                       296.0
# 723                        130.0                       115.0
# 724                        533.0                       268.0
# 1126                       144.0                        64.0
# 1127                       525.0                       268.0
# 1527                       140.0                        73.0
# 1528                       525.0                       298.0
# 1926                       143.0                        65.0
# 1927                       479.0                       223.0
# 2324                       131.0                        27.0
# 2325                       482.0                       240.0
# 2715                       127.0                        74.0
# 2716                       541.0                       265.0
#
#       Total Year-Round Beds (SH)  \
# 313                          0.0
# 314                         50.0
# 723                          0.0
# 724                         25.0
# 1126                         0.0
# 1127                        25.0
# 1527                         0.0
# 1528                        25.0
# 1926                         0.0
# 1927                        25.0
# 2324                         0.0
# 2325                         8.0
# 2715                         0.0
# 2716                        25.0
#
#       Total Units for Households with Children (ES, TH, SH)  \
# 313                                                50.0
# 314                                                91.0
# 723                                                51.0
# 724                                                91.0
# 1126                                               43.0
# 1127                                               91.0
# 1527                                               43.0
# 1528                                               91.0
# 1926                                               36.0
# 1927                                               88.0
# 2324                                               22.0
# 2325                                               95.0
# 2715                                               28.0
# 2716                                               99.0
#
#       Total Beds for Households with Children (ES, TH, SH)  ...  \
# 313                                               138.0     ...
# 314                                               328.0     ...
# 723                                               140.0     ...
# 724                                               328.0     ...
# 1126                                              131.0     ...
# 1127                                              328.0     ...
# 1527                                              128.0     ...
# 1528                                              328.0     ...
# 1926                                              118.0     ...
# 1927                                              241.0     ...
# 2324                                               63.0     ...
# 2325                                              254.0     ...
# 2715                                               72.0     ...
# 2716                                              268.0     ...
#
#       Dedicated Veteran Beds (RRH)  Dedicated Youth Beds (RRH)  \
# 313                            NaN                         NaN
# 314                            NaN                         NaN
# 723                            NaN                         NaN
# 724                            NaN                         NaN
# 1126                           NaN                         NaN
# 1127                           NaN                         NaN
# 1527                           8.0                         3.0
# 1528                          27.0                         7.0
# 1926                           9.0                         4.0
# 1927                          38.0                         7.0
# 2324                           9.0                         2.0
# 2325                          60.0                         7.0
# 2715                           0.0                         2.0
# 2716                          53.0                         7.0
#
#       Dedicated Veteran Beds (PSH)  Dedicated Youth Beds (PSH)  \
# 313                            NaN                         NaN
# 314                            NaN                         NaN
# 723                            NaN                         NaN
# 724                            NaN                         NaN
# 1126                           NaN                         NaN
# 1127                           NaN                         NaN
# 1527                          15.0                         0.0
# 1528                         205.0                         2.0
# 1926                          15.0                         0.0
# 1927                         302.0                         2.0
# 2324                          11.0                         0.0
# 2325                         300.0                         0.0
# 2715                           8.0                         0.0
# 2716                         278.0                         8.0
#
#       Dedicated Chronically Homeless Beds (PSH) Dedicated Veteran Beds (OPH)  \
# 313                                         NaN                          NaN
# 314                                         NaN                          NaN
# 723                                         NaN                          NaN
# 724                                         NaN                          NaN
# 1126                                        NaN                          NaN
# 1127                                        NaN                          NaN
# 1527                                        5.0                          0.0
# 1528                                      225.0                          0.0
# 1926                                       10.0                          0.0
# 1927                                      224.0                          0.0
# 2324                                        9.0                          0.0
# 2325                                      301.0                          0.0
# 2715                                        2.0                          0.0
# 2716                                      303.0                          0.0
#
#       Dedicated Youth Beds (OPH)                    CoC Name   City  State
# 313                          NaN  North Central Oklahoma CoC  tulsa     ok
# 314                          NaN     Tulsa City & County CoC  tulsa     ok
# 723                          NaN  North Central Oklahoma CoC  tulsa     ok
# 724                          NaN     Tulsa City & County CoC  tulsa     ok
# 1126                         NaN  North Central Oklahoma CoC  tulsa     ok
# 1127                         NaN     Tulsa City & County CoC  tulsa     ok
# 1527                         0.0  North Central Oklahoma CoC  tulsa     ok
# 1528                         0.0     Tulsa City & County CoC  tulsa     ok
# 1926                         0.0  North Central Oklahoma CoC  tulsa     ok
# 1927                         0.0     Tulsa City & County CoC  tulsa     ok
# 2324                         0.0  North Central Oklahoma CoC  tulsa     ok
# 2325                         0.0     Tulsa City & County CoC  tulsa     ok
# 2715                         0.0  North Central Oklahoma CoC  tulsa     ok
# 2716                         0.0     Tulsa City & County CoC  tulsa     ok
#
# [14 rows x 97 columns]

# %%
cities = [('sacramento', 'ca'), ('tulsa', 'ok'), ('san diego', 'ca'), ('san antonio', 'tx')];
fig, axes = plt.subplots(len(cities),2,figsize = (20,28));

for i, (city, state) in enumerate(cities):
    city_data = data[(data['City'] == city)&(data['State'] == state)][['Overall Homeless', 'year', 'Sheltered ES Homeless', 'Sheltered TH Homeless','Unsheltered Homeless']]

    df = data_2[(data_2['City'] == city)&(data_2['State'] == state)][['year', 'Total Year-Round Beds (ES, TH, SH)','Total Year-Round Beds (RRH)','Total Year-Round Beds (PSH)', 'Total Year-Round Beds (OPH)']]
    city_HIC_data = df[['year']].copy()
    city_HIC_data['# temporary housing units'] = df['Total Year-Round Beds (ES, TH, SH)'].copy()
    city_HIC_data['# permanent housing units'] = df[['Total Year-Round Beds (RRH)','Total Year-Round Beds (PSH)', 'Total Year-Round Beds (OPH)']].sum(axis=1).copy()    

    sns.lineplot(data=city_data.groupby('year').sum(),ax = axes[i][0])
    axes[i][0].set_title(f'{city}, {state.upper()}');
    axes[i][0].set_ylabel('# homeless')
    axes[i][0].set_facecolor('black');

    sns.lineplot(data=city_HIC_data.groupby('year').sum(),ax = axes[i][1])
    axes[i][1].set_title(f'{city}, {state.upper()}');
    axes[i][1].set_ylabel('HIC');
    axes[i][1].set_facecolor('black');
    
plt.show()
# Out:
# <AxesSubplot:xlabel='year'>
# Text(0.5, 1.0, 'sacramento, CA')
# Text(0, 0.5, '# homeless')
# <AxesSubplot:xlabel='year'>
# Text(0.5, 1.0, 'sacramento, CA')
# Text(0, 0.5, 'HIC')
# <AxesSubplot:xlabel='year'>
# Text(0.5, 1.0, 'tulsa, OK')
# Text(0, 0.5, '# homeless')
# <AxesSubplot:xlabel='year'>
# Text(0.5, 1.0, 'tulsa, OK')
# Text(0, 0.5, 'HIC')
# <AxesSubplot:xlabel='year'>
# Text(0.5, 1.0, 'san diego, CA')
# Text(0, 0.5, '# homeless')
# <AxesSubplot:xlabel='year'>
# Text(0.5, 1.0, 'san diego, CA')
# Text(0, 0.5, 'HIC')
# <AxesSubplot:xlabel='year'>
# Text(0.5, 1.0, 'san antonio, TX')
# Text(0, 0.5, '# homeless')
# <AxesSubplot:xlabel='year'>
# Text(0.5, 1.0, 'san antonio, TX')
# Text(0, 0.5, 'HIC')
