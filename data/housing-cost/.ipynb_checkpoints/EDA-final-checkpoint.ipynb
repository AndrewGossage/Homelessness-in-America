# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Read in Data

# %%
df_2017= pd.read_csv('cleaned/income_2017.csv')
df_2018= pd.read_csv('cleaned/income_2018.csv')
df_2019= pd.read_csv('cleaned/income_2019.csv')

df_homeless = pd.read_csv('../homelessness/homelessness_cleaning/2014-2021-PIT-esimates-cleanish.csv')

# %%
df_h = df_homeless[['Overall Homeless', 'City', 'State', 'year']]

# %%
df_h.head()
# Out:
#    Overall Homeless        City State  year
# 0            1023.0   anchorage    ak  2014
# 1             761.0   anchorage    ak  2014
# 2            1329.0  birmingham    al  2014
# 3             598.0      mobile    al  2014
# 4             209.0    florence    al  2014

# %%
df_2017.head()
# Out:
#          city state  median household income (dollars)_2017  \
# 0   abbeville    la                                   41082
# 1   abbeville    sc                                   22898
# 2  abbotsford    wi                                   42043
# 3    aberdeen    ms                                   29317
# 4    aberdeen    sd                                   47342
#
#    monthly cost_2017  owner occupied income_2017  owner occupied cost_2017  \
# 0                514                       51168                       399
# 1                549                       32998                       572
# 2                608                       53068                       667
# 3                578                       44957                       622
# 4                721                       70839                       840
#
#    renter occupied income_2017  renter occupied cost_2017
# 0                        23326                        643
# 1                        14408                        544
# 2                        28594                        576
# 3                        18199                        537
# 4                        30029                        641

# %% [markdown]
# ## Look at cities with the highest renter costs

# %%
df_2017.sort_values('renter occupied cost_2017' ,ascending=False).head(10)
# Out:
#                                           city state  \
# 2147                            mountain house    ca
# 2098                                   montauk    ny
# 1566         kailua (honolulu county)--kaneohe    hi
# 861                              discovery bay    ca
# 396                    buckhead (bryan county)    ga
# 3488                                yountville    ca
# 3118                             thousand oaks    ca
# 2821                                  san jose    ca
# 2073  mission viejo--lake forest--san clemente    ca
# 2599                               princeville    hi
#
#       median household income (dollars)_2017  monthly cost_2017  \
# 2147                                  120439               2597
# 2098                                   86852               1673
# 1566                                   99375               2143
# 861                                   114148               2264
# 396                                   116280               1960
# 3488                                   70938               1438
# 3118                                  107024               2238
# 2821                                  107171               2154
# 2073                                  100469               2173
# 2599                                   64167               1609
#
#       owner occupied income_2017  owner occupied cost_2017  \
# 2147                      124862                      2618
# 2098                       91154                      1560
# 1566                      117507                      2073
# 861                       119773                      2279
# 396                       119063                      1840
# 3488                       72800                      1130
# 3118                      124856                      2420
# 2821                      135840                      2430
# 2073                      120723                      2366
# 2599                       66875                      1435
#
#       renter occupied income_2017  renter occupied cost_2017
# 2147                        84807                       2561
# 2098                        43750                       2298
# 1566                        70470                       2246
# 861                         93641                       2236
# 396                         93750                       2219
# 3488                        65781                       2012
# 3118                        72723                       1972
# 2821                        78840                       1972
# 2073                        67076                       1935
# 2599                        49688                       1906

# %%
df_2018.sort_values('renter occupied cost_2018' ,ascending=False).head(10)
# Out:
#                                          city state  \
# 188         kailua (honolulu county)--kaneohe    hi
# 346                                  san jose    ca
# 222                                 livermore    ca
# 389                             thousand oaks    ca
# 254  mission viejo--lake forest--san clemente    ca
# 83                                    concord    ca
# 296                                  petaluma    ca
# 57                                  camarillo    ca
# 142                       gilroy--morgan hill    ca
# 344                    san francisco--oakland    ca
#
#      median household income (dollars)_2018  monthly cost_2018  \
# 188                                  101055               2183
# 346                                  127210               2423
# 222                                  135351               2415
# 389                                  112088               2295
# 254                                  109915               2282
# 83                                   130555               2386
# 296                                  100511               2050
# 57                                    91787               2124
# 142                                  118603               2349
# 344                                  105109               2120
#
#      owner occupied income_2018  owner occupied cost_2018  \
# 188                      117880                      1970
# 346                      157447                      2616
# 222                      150971                      2574
# 389                      132194                      2361
# 254                      130622                      2381
# 83                       158042                      2652
# 296                      116072                      2100
# 57                       111007                      2228
# 142                      141368                      2721
# 344                      138009                      2435
#
#      renter occupied income_2018  renter occupied cost_2018
# 188                        68750                       2522
# 346                        95487                       2320
# 222                        79893                       2210
# 389                        77776                       2195
# 254                        75855                       2183
# 83                         86334                       2048
# 296                        71733                       1998
# 57                         76044                       1991
# 142                        82109                       1962
# 344                        79148                       1935

# %%
df_2019.sort_values('renter occupied cost_2019' ,ascending=False).head(10)
# Out:
#                                          city state  \
# 188         kailua (honolulu county)--kaneohe    hi
# 346                                  san jose    ca
# 222                                 livermore    ca
# 389                             thousand oaks    ca
# 84                                    concord    ca
# 254  mission viejo--lake forest--san clemente    ca
# 366                               simi valley    ca
# 350                             santa clarita    ca
# 142                       gilroy--morgan hill    ca
# 58                                  camarillo    ca
#
#      median household income (dollars)_2019  monthly cost_2019  \
# 188                                  106602               2177
# 346                                  133543               2478
# 222                                  136875               2528
# 389                                  117220               2433
# 84                                   136653               2448
# 254                                  113540               2301
# 366                                  100320               2289
# 350                                  103402               2267
# 142                                  118189               2428
# 58                                    91934               2035
#
#      owner occupied income_2019  owner occupied cost_2019  \
# 188                      122603                      2004
# 346                      167708                      2614
# 222                      164309                      2609
# 389                      137011                      2583
# 84                       162411                      2682
# 254                      136697                      2411
# 366                      116155                      2336
# 350                      123980                      2425
# 142                      161396                      2860
# 58                       106019                      2022
#
#      renter occupied income_2019  renter occupied cost_2019
# 188                        70209                       2415
# 346                        98793                       2407
# 222                        95860                       2404
# 389                        81934                       2282
# 84                         93331                       2241
# 254                        76752                       2210
# 366                        80281                       2208
# 350                        65543                       2084
# 142                        72333                       2065
# 58                         71250                       2050

# %% [markdown]
# ### One merged data on housing economic data

# %%
df_merge = df_2017.merge(df_2018, on=['city', 'state'])

df_merge_final = df_merge.merge(df_2019, on=['city', 'state'])

df_merge_final.head()
# Out:
#                                      city state  \
# 0  aberdeen--bel air south--bel air north    md
# 1                                 abilene    tx
# 2       aguadilla--isabela--san sebastián    pr
# 3                                   akron    oh
# 4                                  albany    ga
#
#    median household income (dollars)_2017  monthly cost_2017  \
# 0                                   81761               1390
# 1                                   45943                812
# 2                                   15912                226
# 3                                   49110                818
# 4                                   38015                752
#
#    owner occupied income_2017  owner occupied cost_2017  \
# 0                       96031                      1503
# 1                       61388                       778
# 2                       19894                       184
# 3                       64792                       877
# 4                       60370                       852
#
#    renter occupied income_2017  renter occupied cost_2017  \
# 0                        42310                       1176
# 1                        35184                        837
# 2                        10061                        420
# 3                        28635                        768
# 4                        25685                        714
#
#    median household income (dollars)_2018  monthly cost_2018  \
# 0                                   86876               1374
# 1                                   46387                891
# 2                                   17234                231
# 3                                   53755                836
# 4                                   40667                758
#
#    owner occupied income_2018  owner occupied cost_2018  \
# 0                       98033                      1465
# 1                       59643                       733
# 2                       23313                       182
# 3                       72001                       896
# 4                       53671                       793
#
#    renter occupied income_2018  renter occupied cost_2018  \
# 0                        49084                       1203
# 1                        35904                        941
# 2                        10585                        422
# 3                        31025                        782
# 4                        29169                        741
#
#    median household income (dollars)_2019  monthly cost_2019  \
# 0                                   90166               1388
# 1                                   51913                864
# 2                                   16582                193
# 3                                   51928                834
# 4                                   38440                799
#
#    owner occupied income_2019  owner occupied cost_2019  \
# 0                      103767                      1463
# 1                       69349                       820
# 2                       20611                       172
# 3                       67171                       866
# 4                       56250                       844
#
#    renter occupied income_2019  renter occupied cost_2019
# 0                        52866                       1285
# 1                        36183                        882
# 2                         9248                        412
# 3                        31352                        809
# 4                        21425                        777

# %%
df_merge_final.shape
# Out:
# (435, 20)

# %%
df_2017.shape
# Out:
# (3501, 8)

# %%
df_2018.shape
# Out:
# (438, 8)

# %%
df_2019.shape
# Out:
# (438, 8)

# %% [markdown]
# # Add homeless information in

# %%
df_h.columns = df_h.columns.str.lower()

df_h_2017 = df_h.loc[df_h['year'] == 2017]
df_h_2018 = df_h.loc[df_h['year'] == 2018]
df_h_2019 = df_h.loc[df_h['year'] == 2019]

df_h_2017.shape

# %%
df_2017_w_homless = df_2017.merge(df_h_2017, on=['city', 'state'])
df_2018_w_homless = df_2018.merge(df_h_2018, on=['city', 'state'])
df_2019_w_homless = df_2019.merge(df_h_2019, on=['city', 'state'])

df_2017_w_homless.shape
# Out:
# (192, 10)

# %%
df_2018_w_homless.shape
# Out:
# (130, 10)

# %%
df_2019_w_homless.shape
# Out:
# (130, 10)

# %%
df_2019_w_homless.head()
# Out:
#           city state  median household income (dollars)_2019  \
# 0        akron    oh                                   51928
# 1  albuquerque    nm                                   57603
# 2   alexandria    la                                   45180
# 3     amarillo    tx                                   49735
# 4    anchorage    ak                                   80270
#
#    monthly cost_2019  owner occupied income_2019  owner occupied cost_2019  \
# 0                834                       67171                       866
# 1                978                       71483                      1037
# 2                814                       57644                       730
# 3                862                       66512                       904
# 4               1403                      106725                      1618
#
#    renter occupied income_2019  renter occupied cost_2019  overall homeless  \
# 0                        31352                        809             546.0
# 1                        38258                        917            1524.0
# 2                        35826                        839             114.0
# 3                        32821                        831             777.0
# 4                        49448                       1207            1111.0
#
#    year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %% [markdown]
# ## Look at the cost to income for renters ratio

# %%
df_2019_w_homless['renter_cost_to_income_ratio'] = (df_2019_w_homless['renter occupied cost_2019']*12)/df_2019_w_homless['renter occupied income_2019']
df_2018_w_homless['renter_cost_to_income_ratio'] = (df_2018_w_homless['renter occupied cost_2018']*12)/df_2018_w_homless['renter occupied income_2018']
df_2017_w_homless['renter_cost_to_income_ratio'] = (df_2017_w_homless['renter occupied cost_2017']*12)/df_2017_w_homless['renter occupied income_2017']

# %%
df_2019_w_homless.loc[df_2019_w_homless['renter_cost_to_income_ratio'] > 0.32]
# Out:
#               city state  median household income (dollars)_2019  \
# 6        asheville    nc                                   53283
# 10     bakersfield    ca                                   54215
# 11       baltimore    md                                   78589
# 14            bend    or                                   69280
# 15      birmingham    al                                   58251
# 16       bremerton    wa                                   77345
# 18      burlington    vt                                   68819
# 19       champaign    il                                   49310
# 21           chico    ca                                   62055
# 23        columbia    sc                                   56501
# 25       corvallis    or                                   58633
# 26           davis    ca                                   60128
# 33            erie    pa                                   47534
# 34          eugene    or                                   55359
# 40          fresno    ca                                   60189
# 41     gainesville    fl                                   46781
# 51         jackson    mi                                   43335
# 54         jackson    tn                                   47009
# 60       lafayette    la                                   55509
# 69      manchester    nh                                   71302
# 70         medford    or                                   55389
# 71           miami    fl                                   60073
# 73          mobile    al                                   48446
# 74          monroe    la                                   36280
# 75          muncie    in                                   41671
# 80     new orleans    la                                   52336
# 82           ocala    fl                                   48355
# 84         orlando    fl                                   64174
# 91        richmond    va                                   65978
# 92        richmond    va                                   65978
# 95      sacramento    ca                                   76222
# 96         saginaw    mi                                   39534
# 97   st. augustine    fl                                   64291
# 99       san diego    ca                                   83129
# 101       san juan    pr                                   23646
# 102       san juan    pr                                   23646
# 103     santa cruz    ca                                   94174
# 105    santa maria    ca                                   73031
# 106     santa rosa    ca                                   84439
# 107       savannah    ga                                   57438
# 109     shreveport    la                                   46613
# 110    spartanburg    sc                                   53150
# 112    springfield    il                                   58331
# 114       stockton    ca                                   58808
# 116    tallahassee    fl                                   53084
# 118        trenton    nj                                   73178
# 122     tuscaloosa    al                                   50350
# 125           waco    tx                                   44636
# 128     wilmington    nc                                   57335
#
#      monthly cost_2019  owner occupied income_2019  owner occupied cost_2019  \
# 6                  972                       69502                       933
# 10                1127                       81058                      1306
# 11                1417                      102021                      1513
# 14                1491                       80829                      1481
# 15                 986                       75630                      1034
# 16                1507                       96739                      1564
# 18                1419                      104931                      1648
# 19                 954                       78808                      1016
# 21                1182                       89335                      1301
# 23                 993                       78061                      1031
# 25                1193                       97789                      1301
# 26                1688                      130544                      2017
# 33                 777                       65366                       798
# 34                1134                       79283                      1251
# 40                1194                       85633                      1428
# 41                1000                       81615                       979
# 51                 760                       56413                       727
# 54                 865                       61949                       855
# 60                 853                       76946                       854
# 69                1417                      101992                      1661
# 70                1065                       74533                      1040
# 71                1383                       75197                      1294
# 73                 854                       64094                       862
# 74                 699                       58426                       583
# 75                 680                       60228                       653
# 80                 958                       68306                       930
# 82                 846                       56758                       699
# 84                1271                       81418                      1217
# 91                1197                       90245                      1249
# 92                1197                       90245                      1249
# 95                1510                      101141                      1698
# 96                 687                       52434                       633
# 97                1029                       71264                       990
# 99                1866                      111383                      2127
# 101                449                       29174                       367
# 102                449                       29174                       367
# 103               2005                      112329                      2245
# 105               1481                       85688                      1546
# 106               1819                      104005                      1922
# 107               1118                       73727                      1139
# 109                849                       59784                       826
# 110                855                       66788                       834
# 112                883                       79193                       968
# 114               1229                       75947                      1329
# 116               1042                       84863                      1088
# 118               1391                       95092                      1597
# 122                939                       80605                      1018
# 125                861                       66866                       822
# 128               1153                       80510                      1216
#
#      renter occupied income_2019  renter occupied cost_2019  overall homeless  \
# 6                          36753                       1008             580.0
# 10                         36395                        983            1330.0
# 11                         49399                       1333            2294.0
# 14                         51524                       1501             880.0
# 15                         32513                        940             981.0
# 16                         51983                       1425            5509.0
# 18                         36969                       1277             309.0
# 19                         31750                        936             151.0
# 21                         39843                       1127            1266.0
# 23                         35863                        958            1215.0
# 25                         33650                       1157            7103.0
# 26                         42289                       1699             655.0
# 33                         27664                        760             356.0
# 34                         35530                       1063            2165.0
# 40                         36073                       1082            2508.0
# 41                         32190                       1017             804.0
# 51                         25345                        780             113.0
# 54                         25888                        880             959.0
# 60                         29225                        853             360.0
# 69                         45843                       1223             461.0
# 70                         38467                       1077             712.0
# 71                         44715                       1440            3472.0
# 73                         29082                        848             505.0
# 74                         25691                        745             188.0
# 75                         25823                        696            3904.0
# 80                         32977                        972            1179.0
# 82                         33991                        977             475.0
# 84                         47174                       1307            2010.0
# 91                         40823                       1160             497.0
# 92                         40823                       1160             761.0
# 95                         50818                       1396            5561.0
# 96                         28125                        762             364.0
# 97                         40485                       1102             356.0
# 99                         60435                       1755            8102.0
# 101                        14409                        528            1345.0
# 102                        14409                        528            1190.0
# 103                        66431                       1909            2167.0
# 105                        52576                       1422            1803.0
# 106                        61658                       1740            2951.0
# 107                        38090                       1105             686.0
# 109                        25930                        867             292.0
# 110                        31669                        875            1401.0
# 112                        29545                        813             284.0
# 114                        41075                       1177            2631.0
# 116                        34620                       1022             966.0
# 118                        39120                       1181             448.0
# 122                        31245                        896              44.0
# 125                        30851                        876             193.0
# 128                        38474                       1109             431.0
#
#      year  renter_cost_to_income_ratio
# 6    2019                     0.329116
# 10   2019                     0.324110
# 11   2019                     0.323812
# 14   2019                     0.349585
# 15   2019                     0.346938
# 16   2019                     0.328954
# 18   2019                     0.414509
# 19   2019                     0.353764
# 21   2019                     0.339432
# 23   2019                     0.320553
# 25   2019                     0.412600
# 26   2019                     0.482111
# 33   2019                     0.329670
# 34   2019                     0.359021
# 40   2019                     0.359937
# 41   2019                     0.379124
# 51   2019                     0.369304
# 54   2019                     0.407911
# 60   2019                     0.350248
# 69   2019                     0.320136
# 70   2019                     0.335976
# 71   2019                     0.386448
# 73   2019                     0.349907
# 74   2019                     0.347982
# 75   2019                     0.323433
# 80   2019                     0.353701
# 82   2019                     0.344915
# 84   2019                     0.332471
# 91   2019                     0.340984
# 92   2019                     0.340984
# 95   2019                     0.329647
# 96   2019                     0.325120
# 97   2019                     0.326639
# 99   2019                     0.348474
# 101  2019                     0.439725
# 102  2019                     0.439725
# 103  2019                     0.344839
# 105  2019                     0.324559
# 106  2019                     0.338642
# 107  2019                     0.348123
# 109  2019                     0.401234
# 110  2019                     0.331555
# 112  2019                     0.330208
# 114  2019                     0.343859
# 116  2019                     0.354246
# 118  2019                     0.362270
# 122  2019                     0.344119
# 125  2019                     0.340734
# 128  2019                     0.345896

# %% [markdown]
# # Cities with the highest renter cost to income ratio

# %%
#For 2019
cities_over_32 = df_2019_w_homless.loc[df_2019_w_homless['renter_cost_to_income_ratio'] > 0.32].city.to_list()
value_2019 = df_2019_w_homless.loc[df_2019_w_homless['renter_cost_to_income_ratio'] > 0.32].renter_cost_to_income_ratio.to_list()

len(cities_over_32)

cities_over_32_df_2019 = pd.DataFrame(
    {'city': cities_over_32,
     'ratio_over_32 for 2019': value_2019
    })
 

print(cities_over_32_df_2019.shape)    
cities_over_32_df_2019.sort_values('ratio_over_32 for 2019', ascending=False).head(10)
# Out:
# (49, 2)
#            city  ratio_over_32 for 2019
# 11        davis                0.482111
# 35     san juan                0.439725
# 34     san juan                0.439725
# 6    burlington                0.414509
# 10    corvallis                0.412600
# 17      jackson                0.407911
# 40   shreveport                0.401234
# 21        miami                0.386448
# 15  gainesville                0.379124
# 16      jackson                0.369304

# %%
#For 2018
cities_over_32 = df_2018_w_homless.loc[df_2018_w_homless['renter_cost_to_income_ratio'] > 0.32].city.to_list()
value_2018 = df_2018_w_homless.loc[df_2018_w_homless['renter_cost_to_income_ratio'] > 0.32].renter_cost_to_income_ratio.to_list()

len(cities_over_32)

cities_over_32_df_2018 = pd.DataFrame(
    {'city': cities_over_32,
     'ratio_over_32 for 2018': value_2018
    })

print(cities_over_32_df_2018.shape) 
cities_over_32_df_2018.sort_values('ratio_over_32 for 2018', ascending=False).head(10)
# Out:
# (62, 2)
#            city  ratio_over_32 for 2018
# 12        davis                0.537399
# 47     san juan                0.497929
# 48     san juan                0.497929
# 11    corvallis                0.418338
# 32       muncie                0.416563
# 9    charleston                0.406952
# 5          bend                0.406769
# 21  gainesville                0.397989
# 29        miami                0.393022
# 10        chico                0.388448

# %%
# For 2017
cities_over_32 = df_2017_w_homless.loc[df_2017_w_homless['renter_cost_to_income_ratio'] > 0.32].city.to_list()
value_2017 = df_2017_w_homless.loc[df_2017_w_homless['renter_cost_to_income_ratio'] > 0.32].renter_cost_to_income_ratio.to_list()

len(cities_over_32)

cities_over_32_df_2017 = pd.DataFrame(
    {'city': cities_over_32,
     'ratio_over_32 for 2017': value_2017
    })

print(cities_over_32_df_2017.shape) 
cities_over_32_df_2017.sort_values('ratio_over_32 for 2017', ascending=False).head(10)
# Out:
# (119, 2)
#                city  ratio_over_32 for 2017
# 12            boone                0.784830
# 89            salem                0.634488
# 5            athens                0.559850
# 59         marianna                0.544278
# 93  san luis obispo                0.523668
# 55       lillington                0.517463
# 23            davis                0.505736
# 39           ithaca                0.469504
# 13        bridgeton                0.467836
# 61       metropolis                0.465938

# %%
sns.scatterplot(data = df_2019_w_homless, x='renter occupied cost_2019', 
                y= 'renter occupied income_2019', hue='overall homeless');

# %%
sns.scatterplot(data = df_2019_w_homless, x='overall homeless', y= 'median household income (dollars)_2019');

# %%
sns.scatterplot(data = df_2019_w_homless, x='median household income (dollars)_2019', y= 'overall homeless');

# %%
df_2019_w_homless.columns
# Out:
# Index(['city', 'state', 'median household income (dollars)_2019',
#        'monthly cost_2019', 'owner occupied income_2019',
#        'owner occupied cost_2019', 'renter occupied income_2019',
#        'renter occupied cost_2019', 'overall homeless', 'year',
#        'renter_cost_to_income_ratio'],
#       dtype='object')

# %%
#plt.figure(figsize=(20,30))
fig, axes = plt.subplots(4,2, figsize=(15,15))
sns.scatterplot(data = df_2019_w_homless, x='median household income (dollars)_2019', y= 'overall homeless', ax=axes[0,0])
sns.scatterplot(data = df_2019_w_homless, x='monthly cost_2019', y= 'overall homeless', ax=axes[0,1])
sns.scatterplot(data = df_2019_w_homless, x='owner occupied income_2019', y= 'overall homeless', ax=axes[1,0])
sns.scatterplot(data = df_2019_w_homless, x='owner occupied cost_2019', y= 'overall homeless', ax=axes[1,1])
sns.scatterplot(data = df_2019_w_homless, x='renter occupied income_2019', y= 'overall homeless', ax=axes[2,0])
sns.scatterplot(data = df_2019_w_homless, x='renter occupied cost_2019', y= 'overall homeless', ax=axes[2,1])
sns.scatterplot(data = df_2019_w_homless, x='renter_cost_to_income_ratio', y= 'overall homeless', ax=axes[3,0])

fig.suptitle('2019 Housing Economic Income and Costs', fontsize=40);

# %%
#plt.figure(figsize=(20,30))
fig, axes = plt.subplots(4,2, figsize=(15,15))
sns.scatterplot(data = df_2018_w_homless, x='median household income (dollars)_2018', y= 'overall homeless', ax=axes[0,0])
sns.scatterplot(data = df_2018_w_homless, x='monthly cost_2018', y= 'overall homeless', ax=axes[0,1])
sns.scatterplot(data = df_2018_w_homless, x='owner occupied income_2018', y= 'overall homeless', ax=axes[1,0])
sns.scatterplot(data = df_2018_w_homless, x='owner occupied cost_2018', y= 'overall homeless', ax=axes[1,1])
sns.scatterplot(data = df_2018_w_homless, x='renter occupied income_2018', y= 'overall homeless', ax=axes[2,0])
sns.scatterplot(data = df_2018_w_homless, x='renter occupied cost_2018', y= 'overall homeless', ax=axes[2,1])
sns.scatterplot(data = df_2018_w_homless, x='renter_cost_to_income_ratio', y= 'overall homeless', ax=axes[3,0])

fig.suptitle('2018 Housing Economic Income and Costs', fontsize=40);

# %%
#plt.figure(figsize=(20,30))
fig, axes = plt.subplots(4,2, figsize=(15,15))
sns.scatterplot(data = df_2017_w_homless, x='median household income (dollars)_2017', y= 'overall homeless', ax=axes[0,0])
sns.scatterplot(data = df_2017_w_homless, x='monthly cost_2017', y= 'overall homeless', ax=axes[0,1])
sns.scatterplot(data = df_2017_w_homless, x='owner occupied income_2017', y= 'overall homeless', ax=axes[1,0])
sns.scatterplot(data = df_2017_w_homless, x='owner occupied cost_2017', y= 'overall homeless', ax=axes[1,1])
sns.scatterplot(data = df_2017_w_homless, x='renter occupied income_2017', y= 'overall homeless', ax=axes[2,0])
sns.scatterplot(data = df_2017_w_homless, x='renter occupied cost_2017', y= 'overall homeless', ax=axes[2,1])
sns.scatterplot(data = df_2017_w_homless, x='renter_cost_to_income_ratio', y= 'overall homeless', ax=axes[3,0])

fig.suptitle('2017 Housing Economic Income and Costs', fontsize=40);

# %%
sns.scatterplot(data = df_2019_w_homless, x='owner occupied cost_2019', y= 'overall homeless');

# %%
plt.figure(figsize=(16,20))
sns.pairplot(df_2019_w_homless, corner=True);

# %%
df_2019_w_homless.columns
# Out:
# Index(['city', 'state', 'median household income (dollars)_2019',
#        'monthly cost_2019', 'owner occupied income_2019',
#        'owner occupied cost_2019', 'renter occupied income_2019',
#        'renter occupied cost_2019', 'overall homeless', 'year',
#        'renter_cost_to_income_ratio'],
#       dtype='object')

# %%
plt.figure(figsize=(50,50))
sns.set(font_scale=1)

sns.pairplot(data = df_2019_w_homless,
             x_vars=['median household income (dollars)_2019',
       'monthly cost_2019', 'owner occupied income_2019',
       'owner occupied cost_2019', 'renter occupied income_2019',
       'renter occupied cost_2019',
       'renter_cost_to_income_ratio'],
             y_vars=['overall homeless']
             
            
)

#plt.show()

# %%
plt.figure(figsize=(16,20))
sns.pairplot(df_2018_w_homless, corner=True);

# %%
plt.figure(figsize=(16,20))
sns.pairplot(df_2017_w_homless, corner=True);

# %% [markdown]
# # Linear Regression model

# %%
df_2019_w_homless.columns
# Out:
# Index(['city', 'state', 'median household income (dollars)_2019',
#        'monthly cost_2019', 'owner occupied income_2019',
#        'owner occupied cost_2019', 'renter occupied income_2019',
#        'renter occupied cost_2019', 'overall homeless', 'year',
#        'renter_cost_to_income_ratio'],
#       dtype='object')

# %%
X = df_2019_w_homless.drop(columns=['overall homeless', 'year','city', 'state'])
y = df_2019_w_homless['overall homeless']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train, y_train)
# Out:
# 0.339937339293482

# %%
lr.coef_
# Out:
# array([-6.71299473e-02, -5.50589252e+00,  2.80664582e-02,  3.41598652e+00,
#        -3.13877229e-02,  6.94534410e+00,  9.18355008e+02])

# %%
pd.DataFrame({
    'Features': X_train.columns,
    'Coef': lr.coef_
})
# Out:
#                                  Features        Coef
# 0  median household income (dollars)_2019   -0.067130
# 1                       monthly cost_2019   -5.505893
# 2              owner occupied income_2019    0.028066
# 3                owner occupied cost_2019    3.415987
# 4             renter occupied income_2019   -0.031388
# 5               renter occupied cost_2019    6.945344
# 6             renter_cost_to_income_ratio  918.355008

# %% [markdown]
# ## For 2019

# %%
X = df_2019_w_homless.drop(columns=['overall homeless', 'year','city', 'state'])
y = df_2019_w_homless['overall homeless']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

lr_2019 = LinearRegression()
lr_2019.fit(X_train, y_train)

print(lr_2019.score(X_train, y_train))

pd.DataFrame({
    'Features': X_train.columns,
    'Coef': lr_2019.coef_
})
# Out:
# 0.339937339293482
#                                  Features        Coef
# 0  median household income (dollars)_2019   -0.067130
# 1                       monthly cost_2019   -5.505893
# 2              owner occupied income_2019    0.028066
# 3                owner occupied cost_2019    3.415987
# 4             renter occupied income_2019   -0.031388
# 5               renter occupied cost_2019    6.945344
# 6             renter_cost_to_income_ratio  918.355008

# %% [markdown]
# ## for 2018

# %%
X = df_2018_w_homless.drop(columns=['overall homeless', 'year','city', 'state'])
y = df_2018_w_homless['overall homeless']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

lr_2018 = LinearRegression()
lr_2018.fit(X_train, y_train)

print(lr_2018.score(X_train, y_train))

pd.DataFrame({
    'Features': X_train.columns,
    'Coef': lr_2018.coef_
})
# Out:
# 0.34944655311521067
#                                  Features         Coef
# 0  median household income (dollars)_2018     0.044742
# 1                       monthly cost_2018   -19.515018
# 2              owner occupied income_2018    -0.049858
# 3                owner occupied cost_2018    10.321763
# 4             renter occupied income_2018     0.014486
# 5               renter occupied cost_2018    11.724198
# 6             renter_cost_to_income_ratio  8931.353339

# %% [markdown]
# ## For 2017

# %%
X = df_2017_w_homless.drop(columns=['overall homeless', 'year','city', 'state'])
y = df_2017_w_homless['overall homeless']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

lr_2017 = LinearRegression()
lr_2017.fit(X_train, y_train)

print(lr_2017.score(X_train, y_train))

pd.DataFrame({
    'Features': X_train.columns,
    'Coef': lr_2017.coef_
})
# Out:
# 0.2038597942362319
#                                  Features         Coef
# 0  median household income (dollars)_2017    -0.036637
# 1                       monthly cost_2017     2.180916
# 2              owner occupied income_2017    -0.001702
# 3                owner occupied cost_2017    -0.163127
# 4             renter occupied income_2017     0.130459
# 5               renter occupied cost_2017    -2.578876
# 6             renter_cost_to_income_ratio  5632.236849

# %% [markdown]
# ## 2019 Scaled

# %%
X = df_2019_w_homless.drop(columns=['overall homeless', 'year','city', 'state'])
y = df_2019_w_homless['overall homeless']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

lr_2019_sc = LinearRegression()
lr_2019_sc.fit(X_train_sc, y_train)

print(lr_2019_sc.score(X_train_sc, y_train))

inv_scaled = sc.inverse_transform(lr_2019_sc.coef_)

pd.DataFrame({
    'Features': X_train.columns,
    'Coef': inv_scaled
})
#'Coef': lr_2019_sc.coef_
# Out:
# 0.3399373392934819
#                                  Features          Coef
# 0  median household income (dollars)_2019 -1.079797e+07
# 1                       monthly cost_2019 -4.270784e+05
# 2              owner occupied income_2019  7.008166e+06
# 3                owner occupied cost_2019  3.869031e+05
# 4             renter occupied income_2019 -2.873983e+06
# 5               renter occupied cost_2019  4.350574e+05
# 6             renter_cost_to_income_ratio  1.609821e+00

# %%
X = df_2019_w_homless.drop(columns=['overall homeless', 'year','city', 'state'])
y = df_2019_w_homless['overall homeless']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

lr_2019_sc = LinearRegression()
lr_2019_sc.fit(X_train_sc, y_train)

print(lr_2019_sc.score(X_train_sc, y_train))

#nv_scaled = sc.inverse_transform(lr_2019_sc.coef_)

pd.DataFrame({
    'Features': X_train.columns,
    'Coef': lr_2019_sc.coef_
})
#
# Out:
# 0.3399373392934819
#                                  Features         Coef
# 0  median household income (dollars)_2019  -853.704643
# 1                       monthly cost_2019 -1535.282325
# 2              owner occupied income_2019   441.022160
# 3                owner occupied cost_2019  1148.028355
# 4             renter occupied income_2019  -302.320979
# 5               renter occupied cost_2019  1736.310797
# 6             renter_cost_to_income_ratio    34.481055

# %%
#Andrews 25 cities
Andrews_25_cities= ['albuquerque', 'atlanta', 'austin', 'baltimore', 'baton rouge',
       'birmingham', 'buffalo', 'cleveland', 'columbus', 'detroit',
       'houston', 'indianapolis', 'jacksonville', 'madison', 'miami',
       'milwaukee', 'new orleans', 'pittsburgh', 'raleigh', 'sacramento',
       'san antonio', 'san diego', 'tucson', 'tulsa', 'wichita']
